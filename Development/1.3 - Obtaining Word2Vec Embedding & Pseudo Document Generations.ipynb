# %% [markdown]
# # Obtaining Word Embedding

# %% [markdown]
# import packages

# %%
import warnings
from collections import Counter
import itertools

warnings.filterwarnings(action='ignore')

# %%
import pandas as pd
import numpy as np
import re
from gensim.models import Word2Vec, KeyedVectors, Phrases
from gensim.parsing.preprocessing import strip_short,strip_punctuation,\
                                         strip_numeric, strip_multiple_whitespaces
from gensim.test.utils import get_tmpfile
import glob
from nltk import tokenize
from nltk.corpus import stopwords
import inflect
from spherecluster import  VonMisesFisherMixture

# %%
articles = [] 
for i in glob.glob('./extracted_papers/*.txt'):
    paper = open(i, encoding='utf-8')
    articles.append(paper.read())

# %% [markdown]
# Clear out newline characters and non-unicode characters

# %%
a = ''.join([chr(n) for n in range(256)])
unwanted = '[' + re.escape(''.join([n for n in a if ord(n) < 32 or ord(n) > 126])) + ']'
cleaned_articles = list(map(lambda x: re.sub(unwanted, ' ', x), articles))
cleaned_articles = list(map(lambda x:x.lower(), cleaned_articles))

# %% [markdown]
# Strip out characters that are less than 1

# %%
def preprocess_text(s):
    """Remove unwanted text formats with numeric, whitespace, punctuation, short words stripped 
       Input: text string
       Output: post processed string
    """
    s = strip_numeric(s)
    s = strip_multiple_whitespaces(s)
    s = strip_punctuation(s)
    s = strip_short(s, minsize = 2)
    
    return s

# %%
cleaned_articles = list(map(preprocess_text, cleaned_articles))

# %% [markdown]
# Remove all non-alphabetical charaters

# %%
cleaned_sentences = []
for i in cleaned_articles:
    cleaned_sentences += list(map(lambda x: x, tokenize.sent_tokenize(i)))

# %%
stop_words = set(stopwords.words('english') + ['’','“', '‘', 'within', 
                                               'however','”','\uf8f6\uf8f7\uf8f7\uf8f7\uf8f8'])

# %% [markdown]
# Strip stopwords, tokenize sentence to words

# %%
# cleaned_sentences_w = list(map(lambda sentence: tokenize.word_tokenize(sentence), cleaned_sentences))
cleaned_sentences_w = list(map(lambda sentence: [w for w in tokenize.word_tokenize(sentence) if not w in stop_words], 
                               cleaned_sentences))

# %% [markdown]
# turn all words to singular

# %%
def singularize(sentence):
    p = inflect.engine()
    for i,word in enumerate(sentence):
        if p.singular_noun(word):
            sentence[i] = p.singular_noun(word)
    return sentence
        
cleaned_sentences_w = list(map(singularize, cleaned_sentences_w))

# %% [markdown]
# bigram transform

# %%
bigram_transformer = Phrases(cleaned_sentences_w)

# %% [markdown]
# Train Word2Vec using gensim

# %%
model = Word2Vec(list(bigram_transformer[cleaned_sentences_w]), window= 5, min_count= 3, size= 200)
model.train(cleaned_sentences_w,total_examples=len(cleaned_sentences_w),epochs=50)
# Out:
# (290372552, 328155500)

# %%
model.wv.most_similar ('derivative', topn = 20)
# Out:
# [('payoff', 0.5001509189605713),
#  ('option', 0.44860589504241943),
#  ('integral', 0.4365573227405548),
#  ('superhedging_price', 0.3820866048336029),
#  ('differentiating', 0.3772635757923126),
#  ('expectation', 0.375134140253067),
#  ('marginal', 0.357364684343338),
#  ('derivate', 0.3567274212837219),
#  ('delta', 0.3548198640346527),
#  ('payoff_function', 0.34959232807159424),
#  ('∂', 0.342562735080719),
#  ('moment', 0.3422113060951233),
#  ('differential', 0.3385683000087738),
#  ('schole', 0.33236658573150635),
#  ('partial_derivative', 0.3323553800582886),
#  ('arbitrage', 0.3317824602127075),
#  ('option_payoff', 0.32606762647628784),
#  ('vanilla', 0.32598644495010376),
#  ('operator', 0.3222822844982147),
#  ('unprotected_portfolio', 0.32208162546157837)]

# %% [markdown]
# Get word embedding

# %%
#word_vectors = get_tmpfile("word vectors.kv")
model.wv.save("word vectors.kv")

# %% [markdown]
# Build vocabulary inventory

# %%
def build_vocab(sentences):
    # Build vocabulary
    word_counts = Counter(itertools.chain(*sentences))
    # Mapping from index to word
    vocabulary_inv = [x[0] for x in word_counts.most_common()]
    # Mapping from word to index
    vocabulary = {x: i for i, x in enumerate(vocabulary_inv)}
    return word_counts, vocabulary, vocabulary_inv

# %%
word_counts = Counter(itertools.chain(*list(bigram_transformer[cleaned_sentences_w])))
vocabulary_inv = [x[0] for x in word_counts.most_common()]
vocabulary = {x: i for i, x in enumerate(vocabulary_inv)} # rank words from importance

# %% [markdown]
# Load saved word vectors

# %%
filename = "word vectors.kv"
model = KeyedVectors.load(filename, mmap='r')

# %%
word_embedding = model.wv.vectors 
vocab = list(model.wv.vocab)

# %% [markdown]
# Normalize word embedding weights

# %%
linfnorm = np.linalg.norm(word_embedding, axis=1, ord=2)
word_embedding_normalized = word_embedding / linfnorm[:,None]

# %%
words_df = pd.DataFrame(word_embedding_normalized.T, columns=vocab)

# %%
words_df[['equity','stock', 'fixed_income', 'bond','real_estate','derivative', 'cds', 'swap', 'mortgage']]
# Out:
#        equity     stock  fixed_income      bond  real_estate  derivative  \
# 0   -0.077254 -0.035838     -0.026334 -0.033983     0.032944    0.088212
# 1    0.039362  0.031508     -0.049707  0.056490    -0.085481    0.003974
# 2   -0.020444  0.005016      0.001798  0.056177    -0.062651    0.002750
# 3   -0.017430 -0.088992      0.047215  0.051243    -0.080043   -0.037357
# 4    0.027510  0.064764      0.059560  0.064073     0.092872   -0.040440
# 5    0.039634  0.130758      0.033730 -0.043517    -0.064624   -0.002343
# 6    0.107616 -0.018249      0.008828  0.003732    -0.011873    0.169280
# 7    0.064094  0.127592     -0.055271 -0.008005     0.018048   -0.061576
# 8    0.139534  0.023347     -0.110026  0.085256    -0.016133   -0.123957
# 9   -0.145650  0.008573      0.056150  0.080369     0.020935    0.045687
# 10   0.034660 -0.092879      0.025088 -0.001314    -0.012120    0.010589
# 11   0.010195 -0.135336      0.043620  0.025628    -0.014484   -0.010083
# 12   0.022958  0.068885      0.119480  0.064071    -0.007656    0.087620
# 13  -0.151871  0.074696     -0.117520  0.019347    -0.032915   -0.056819
# 14   0.091761 -0.016871      0.088640 -0.013006    -0.038061    0.053083
# 15  -0.033765 -0.023885     -0.018878  0.001700    -0.041823   -0.060051
# 16   0.095944 -0.045946      0.001159 -0.018201     0.025218   -0.065551
# 17   0.089548  0.073283     -0.026339  0.004054    -0.006806    0.030509
# 18   0.004938  0.074493      0.044155 -0.056982     0.018357   -0.045565
# 19  -0.024082  0.042232     -0.132000  0.094545     0.164369   -0.122126
# 20   0.073230 -0.047685     -0.055111 -0.038463    -0.022214    0.052117
# 21  -0.137020 -0.052621      0.010052 -0.045221    -0.046934   -0.029619
# 22   0.050937  0.057115      0.021703  0.006132    -0.119175   -0.080995
# 23   0.043741 -0.021207      0.033082  0.116882     0.067460    0.004861
# 24  -0.061986 -0.055084     -0.031016  0.026766     0.059278   -0.015386
# 25  -0.016425 -0.018363     -0.154033 -0.056294     0.145477    0.007876
# 26  -0.068089  0.047393      0.053773 -0.023508    -0.086778   -0.031765
# 27   0.057831 -0.032246      0.038508  0.089771    -0.037999   -0.047896
# 28   0.137390 -0.031622      0.093018 -0.018424    -0.032483    0.072021
# 29   0.034483 -0.061932      0.039290 -0.044295     0.021240    0.050007
# ..        ...       ...           ...       ...          ...         ...
# 170 -0.055412  0.116285      0.018245  0.046682     0.142742   -0.095026
# 171 -0.006475 -0.023647     -0.011541 -0.135565    -0.053224    0.041541
# 172 -0.140134 -0.104808     -0.049735 -0.083847     0.067607    0.006874
# 173  0.079373  0.026674     -0.106959  0.174396     0.033904    0.042625
# 174 -0.061340 -0.022890     -0.120368 -0.160655     0.095059    0.011726
# 175  0.021179 -0.104824     -0.051854 -0.036307    -0.037178   -0.038155
# 176 -0.000177  0.041012      0.079577 -0.019514    -0.029801   -0.003145
# 177 -0.058275 -0.001250     -0.033706  0.036888     0.054968    0.014112
# 178  0.029900 -0.012003      0.083793  0.059629    -0.026394    0.010387
# 179  0.026959 -0.063208      0.024297  0.020440     0.011293    0.017634
# 180  0.071276  0.020869     -0.072563 -0.001018    -0.009616    0.016195
# 181 -0.022899  0.014037     -0.039369  0.028234     0.077330   -0.042024
# 182  0.010740  0.092475     -0.053209 -0.032091     0.134127    0.060030
# 183  0.069008  0.098538     -0.067185 -0.102087    -0.112764    0.189309
# 184 -0.014442 -0.005091      0.052423 -0.034004    -0.068073   -0.012752
# 185  0.001089 -0.024020     -0.094005  0.148847    -0.068711    0.135363
# 186  0.004822  0.030034      0.013140  0.050434     0.051104    0.032340
# 187  0.075831 -0.000756     -0.021692  0.064116     0.012521    0.014342
# 188 -0.002574  0.004295     -0.106448  0.010087    -0.069340   -0.000369
# 189 -0.010014 -0.009902     -0.024255 -0.070140    -0.030272   -0.017613
# 190  0.052610  0.006322      0.031238 -0.031001    -0.012028   -0.032236
# 191 -0.059635  0.054552     -0.032835  0.062310    -0.058413    0.169006
# 192  0.062831  0.065715     -0.000635  0.050724     0.015212    0.065277
# 193 -0.064677 -0.009561      0.065439 -0.019506     0.000848    0.042525
# 194 -0.038669 -0.022610      0.077055 -0.013663    -0.026754   -0.050882
# 195 -0.015209 -0.021243      0.038768 -0.072424    -0.015804    0.026011
# 196 -0.126476  0.030931      0.023696 -0.108488    -0.094810   -0.105340
# 197 -0.147664  0.061978      0.047925 -0.069773     0.161793   -0.019725
# 198 -0.038360  0.097939     -0.086172  0.028516     0.063221    0.005498
# 199 -0.010336 -0.067312     -0.150592 -0.056876    -0.023882   -0.021846
#
#           cds      swap  mortgage
# 0    0.010290 -0.046953  0.177935
# 1   -0.088718  0.036078 -0.046988
# 2    0.005555  0.067241  0.113706
# 3   -0.157706 -0.018426 -0.027340
# 4   -0.039156 -0.005243 -0.045293
# 5   -0.062548 -0.157512  0.043281
# 6    0.068275 -0.063931 -0.015851
# 7   -0.076956  0.140811  0.041247
# 8   -0.054268  0.013236 -0.016501
# 9    0.057878  0.034731  0.078502
# 10   0.026928  0.024939 -0.078373
# 11   0.015829 -0.031653 -0.109435
# 12  -0.169885 -0.023868  0.067366
# 13  -0.013384 -0.001800 -0.050760
# 14   0.018724  0.093134  0.014869
# 15   0.028836 -0.070901  0.054170
# 16   0.122381  0.100085  0.020193
# 17   0.060676  0.122983 -0.064383
# 18   0.037252 -0.012826  0.077276
# 19   0.029379  0.012186 -0.020496
# 20  -0.077238  0.063648  0.013845
# 21   0.030682 -0.054400 -0.048519
# 22   0.023851 -0.001959  0.021161
# 23  -0.203569 -0.011911 -0.064603
# 24  -0.038847 -0.070984  0.112175
# 25   0.165779  0.081057 -0.022125
# 26   0.039709  0.111547  0.000212
# 27   0.028213 -0.022077  0.071870
# 28  -0.187302  0.022550  0.100734
# 29   0.068827  0.044429  0.007387
# ..        ...       ...       ...
# 170  0.022561  0.037322 -0.176202
# 171  0.086682 -0.030017  0.071314
# 172 -0.001383  0.101634  0.085554
# 173 -0.027653  0.024732 -0.147090
# 174 -0.041825 -0.009601 -0.069283
# 175 -0.086909 -0.097657  0.144314
# 176  0.004063  0.043376  0.138841
# 177 -0.174243 -0.020574 -0.116210
# 178 -0.008807  0.023050 -0.006924
# 179 -0.005628 -0.016764 -0.027242
# 180 -0.006577 -0.074353 -0.119326
# 181  0.072177  0.001693 -0.005252
# 182 -0.077805 -0.035201 -0.041724
# 183 -0.075718  0.058821 -0.088127
# 184 -0.001176  0.019718  0.075218
# 185 -0.007866  0.076058  0.040873
# 186 -0.002288  0.049405 -0.102273
# 187 -0.067503  0.068970  0.063523
# 188 -0.018593 -0.011509 -0.037408
# 189  0.059981  0.020960  0.013488
# 190  0.142739  0.057831  0.116791
# 191 -0.040170 -0.131190  0.041899
# 192 -0.063481  0.032375 -0.108855
# 193  0.061720 -0.075461 -0.082091
# 194 -0.022561 -0.067534 -0.007497
# 195  0.086038 -0.103734  0.018540
# 196 -0.015601  0.051275 -0.023181
# 197  0.118568  0.037460 -0.022629
# 198 -0.064648 -0.074688  0.098297
# 199  0.056865 -0.063895  0.023282
#
# [200 rows x 9 columns]

# %% [markdown]
# load classes and keywords

# %%
class_keywords_str  = open('class keywords.txt', encoding='utf-8').read()
class_keywords = {i.split(': ')[0]: i.split(': ')[1].split(', ') for i in class_keywords_str.split('\n')}

# %% [markdown]
# Obtain word vectors for each keyword from every class

# %%
class_keywords_supplied = {class_label: [np.array(words_df[word]) for word in words] 
                           for class_label, words in class_keywords.items()}

# %% [markdown]
# fit a vMF distribution for every class, obtain cluster centers and dispersion parameters

# %%
mu = []
kappa = []
for i in class_keywords_supplied.keys():
    keyword_mtx = np.vstack(class_keywords_supplied[i])
    vmF = VonMisesFisherMixture(n_clusters=1, n_jobs=10)
    vmF.fit(keyword_mtx)
    mu.append(vmF.cluster_centers_[0])
    kappa.append(vmF.concentrations_[0])
