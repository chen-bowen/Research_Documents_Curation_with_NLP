# %%
import os

# %%
os.listdir('./papers')
# Out:
# ['Four_Points_Beginner_Risk_Managers_Should_Learn_from_Jeff_Holman_s_Mistakes_in_the_Discussion_of_Antifragile.pdf',
#  'An_Optimization_Method_For_Slice_Interpolation_Of_Medical_Images.pdf',
#  'Intertemporal_Substitutability_Risk_Aversion_and_Asset_Prices.pdf',
#  'A_Quantum_like_Approach_to_the_Stock_Market.pdf',
#  'Existence_of_an_endogenously_complete_equilibrium_driven_by_a_diffusion.pdf',
#  'Cancer_gene_prioritization_by_integrative_analysis_of_mRNA_expression_and_DNA_copy_number_data_a_comparative_review.pdf',
#  'An_Optimized_Microeconomic_Modeling_System_for_Analyzing_Industrial_Externalities_in_Non_OECD_Countries.pdf',
#  'Returns_in_futures_markets_and_\xce\xbd_3_t_distribution.pdf',
#  'Leptokurtic_Portfolio_Theory.pdf',
#  'Interest_prohibition_and_financial_product_innovation.pdf',
#  'Multivariate_Density_Modeling_for_Retirement_Finance.pdf',
#  'Free_Lunch.pdf',
#  'Minimizing_Shortfall.pdf',
#  'BiEntropy_The_Approximate_Entropy_of_a_Finite_Binary_String.pdf',
#  'Is_mathematics_able_to_give_insight_into_current_questions_in_finance_economics_and_politics.pdf',
#  'Inflation_and_unemployment_in_Switzerland_from_1970_to_2050.pdf',
#  'Early_exercise_boundary_for_American_type_of_floating_strike_Asian_option_and_its_numerical_approximation.pdf',
#  'Engineering_Relative_Compression_of_Genomes.pdf',
#  'Factor_Models_for_Cancer_Signatures.pdf',
#  'Asymmetric_return_rates_and_wealth_distribution_influenced_by_the_introduction_of_technical_analysis_into_a_behavioral_agent_based_model.pdf',
#  'Systematic_and_multifactor_risk_models_revisited.pdf',
#  'Coupled_continuous_time_random_walks_in_finance.pdf',
#  'Black_Litterman_model_with_intuitionistic_fuzzy_posterior_return.pdf',
#  'Computation_of_biochemical_pathway_fluctuations_beyond_the_linear_noise_approximation_using_iNA.pdf',
#  'BOOST_A_fast_approach_to_detecting_gene_gene_interactions_in_genome_wide_case_control_studies.pdf',
#  'Significance_of_log_periodic_signatures_in_cumulative_noise.pdf',
#  'Black_Magic_Investigation_Made_Simple_Monte_Carlo_Simulations_and_Historical_Back_Testing_of_Momentum_Cross_Over_Strategies_Using_FRACTI_Patterns.pdf',
#  'Causalities_of_the_Taiwan_Stock_Market.pdf',
#  'Schumpeterian_economic_dynamics_as_a_quantifiable_minimum_model_of_evolution.pdf',
#  'Modelling_Cell_Cycle_using_Different_Levels_of_Representation.pdf',
#  'Frontiers_of_finance_Evolution_and_efficient_markets.pdf',
#  'Can_inferred_provenance_and_its_visualisation_be_used_to_detect_erroneous_annotation_A_case_study_using_UniProtKB.pdf',
#  'Fund_Characteristics_and_Performances_of_Socially_Responsible_Mutual_Funds_Do_ESG_Ratings_Play_a_Role.pdf',
#  'Power_laws_and_market_crashes.pdf',
#  'Survey_data_and_Bayesian_analysis_a_cost_efficient_way_to_estimate_customer_equity.pdf',
#  'Functionals_of_Exponential_Brownian_Motion_and_Divided_Differences.pdf',
#  'Density_of_Skew_Brownian_motion_and_its_functionals_with_application_in_finance.pdf',
#  'A_flexible_architecture_for_modeling_and_simulation_of_diffusional_association.pdf',
#  'Is_the_public_sector_of_your_country_a_diffusion_borrower_Empirical_evidence_from_Brazil.pdf',
#  'Predictive_Modelling_of_Toxicity_Resulting_from_Radiotherapy_Treatments_of_Head_and_Neck_Cancer.pdf',
#  'What_is_Fair_Pay_for_Executives_An_Information_Theoretic_Analysis_of_Wage_Distributions.pdf',
#  'Correlated_adaptation_of_agents_in_a_simple_market_a_statistical_physics_perspective.pdf',
#  'On_Stable_Pareto_Laws_in_a_Hierarchical_Model_of_Economy.pdf',
#  'A_hybrid_tree_finite_difference_approach_for_Heston_Hull_White_type_models.pdf',
#  'Structure_and_Evolution_of_the_World_Trade_Network.pdf',
#  'Mathematical_analysis_of_long_tail_economy_using_stochastic_ranking_processes.pdf',
#  'Complex_Independent_Component_Analysis_of_Frequency_Domain_Electroencephalographic_Data.pdf',
#  'Exponential_wealth_distribution_in_different_discrete_economic_models.pdf',
#  'Fractional_Brownian_motion_with_zero_Hurst_parameter_a_rough_volatility_viewpoint.pdf',
#  'Relationship_between_degree_of_efficiency_and_prediction_in_stock_price_changes.pdf',
#  'Least_quartic_Regression_Criterion_with_Application_to_Finance.pdf',
#  'Mining_Temporal_Patterns_from_iTRAQ_Mass_Spectrometry_LC_MS_MS_Data.pdf',
#  'Record_statistics_for_biased_random_walks_with_an_application_to_financial_data.pdf',
#  'Asymptotic_equivalence_and_sufficiency_for_volatility_estimation_under_microstructure_noise.pdf',
#  'On_Pareto_theory_of_circulation_of_elites.pdf',
#  'Threshold_levels_in_Economics.pdf',
#  'A_Probabilistic_Model_For_Sequence_Analysis.pdf',
#  'Manipulating_decision_making_of_typical_agents.pdf',
#  'A_Spectral_Analysis_of_Business_Cycle_Patterns_in_UK_Sectoral_Output.pdf',
#  'Anomalous_waiting_times_in_high_frequency_financial_data.pdf',
#  'Exact_Simulation_of_Non_stationary_Reflected_Brownian_Motion.pdf',
#  'Modeling_biological_systems_with_delays_in_Bio_PEPA.pdf',
#  'Scaling_and_Multi_scaling_in_Financial_Markets.pdf',
#  'The_quantitative_condition_is_necessary_in_guaranteeing_the_validity_of_the_adiabatic_approximation.pdf',
#  'Quantile_Correlations_Uncovering_temporal_dependencies_in_financial_time_series.pdf',
#  'Visualizing_Treasury_Issuance_Strategy.pdf',
#  'The_Australian_Phillips_curve_and_more.pdf',
#  'Credit_models_and_the_crisis_or_how_I_learned_to_stop_worrying_and_love_the_CDOs.pdf',
#  'Effective_Clustering_Algorithms_for_Gene_Expression_Data.pdf',
#  'Comment_on_recent_claims_by_Sornette_and_Zhou.pdf',
#  'A_Theory_of_Pragmatic_Information_and_Its_Application_to_the_Quasispecies_Model_of_Biological_Evolution.pdf',
#  'A_Modified_Levy_Jump_Diffusion_Model_Based_on_Market_Sentiment_Memory_for_Online_Jump_Prediction.pdf',
#  'Market_bubbles_and_crashes.pdf',
#  'A_subsystems_approach_for_parameter_estimation_of_ODE_models_of_hybrid_systems.pdf',
#  'The_US_2000_2003_Market_Descent_Clarifications.pdf',
#  'Integration_of_a_Predictive_Continuous_Time_Neural_Network_into_Securities_Market_Trading_Operations.pdf',
#  'Mathematical_and_computational_modeling_for_describing_the_basic_behavior_of_free_radicals_and_antioxidants_within_epithelial_cells.pdf',
#  'MRFalign_Protein_Homology_Detection_through_Alignment_of_Markov_Random_Fields.pdf',
#  'A_quantitative_analysis_of_the_effect_of_flexible_loads_on_reserve_markets.pdf',
#  'Physical_approach_to_price_momentum_and_its_application_to_momentum_strategy.pdf',
#  'Accurate_prediction_of_gene_expression_by_integration_of_DNA_sequence_statistics_with_detailed_modeling_of_transcription_regulation.pdf',
#  'DNA_Sequencing_via_Quantum_Mechanics_and_Machine_Learning.pdf',
#  'Efficient_Two_Stage_Group_Testing_Algorithms_for_DNA_Screening.pdf',
#  'Gene_Ontology_GO_Prediction_using_Machine_Learning_Methods.pdf',
#  'Simplicial_models_of_social_aggregation_I.pdf',
#  'A_game_theoretic_derivation_of_the_sqrt_dt_effect.pdf',
#  'Long_term_memories_of_developed_and_emerging_markets_using_the_scaling_analysis_to_characterize_their_stage_of_development.pdf',
#  'Near_optimal_RNA_Seq_quantification.pdf',
#  'Modeling_and_Solving_Alternative_Financial_Solutions_Seeking.pdf',
#  'The_Value_of_Information_for_Populations_in_Varying_Environments.pdf',
#  'Data_visualization_in_political_and_social_sciences.pdf',
#  'Bridging_stylized_facts_in_finance_and_data_non_stationarities.pdf',
#  'The_Interrupted_Power_Law_and_The_Size_of_Shadow_Banking.pdf',
#  'Faster_exon_assembly_by_sparse_spliced_alignment.pdf',
#  'Price_Impact.pdf',
#  'QuickProbs_2_towards_rapid_construction_of_high_quality_alignments_of_large_protein_families.pdf',
#  'Hedging_with_Small_Uncertainty_Aversion.pdf',
#  'What_Makes_An_Asset_Useful.pdf',
#  'A_fitness_model_for_the_Italian_Interbank_Money_Market.pdf',
#  'Multiple_time_scales_and_the_exponential_Ornstein_Uhlenbeck_stochastic_volatility_model.pdf',
#  'A_stochastic_model_for_speculative_bubbles.pdf',
#  'Using_pseudo_parabolic_and_fractional_equations_for_option_pricing_in_jump_diffusion_models.pdf',
#  'Nonlinear_PDEs_risen_when_solving_some_optimization_problems_in_finance_and_their_solutions.pdf',
#  'Emergent_quantum_mechanics_of_finances.pdf',
#  'Technical_report_CSVM_dictionaries.pdf',
#  'Multiplicative_noise_fast_convolution_and_pricing.pdf',
#  'On_a_difference_between_quantitative_weak_sequential_completeness_and_the_quantitative_Schur_property.pdf',
#  'Quantitative_Measure_of_Stability_in_Gene_Regulatory_Networks.pdf',
#  'Stock_returns_versus_trading_volume_is_the_correspondence_more_general.pdf',
#  'Holder_extendible_European_option_corrections_and_extensions.pdf',
#  'Are_news_important_to_predict_large_losses.pdf',
#  'Structure_and_temporal_change_of_the_credit_network_between_banks_and_large_firms_in_Japan.pdf',
#  'No_such_thing_as_a_risk_neutral_market.pdf',
#  'Calculation_of_aggregate_loss_distributions.pdf',
#  'Exploiting_the_Accumulated_Evidence_for_Gene_Selection_in_Microarray_Gene_Expression_Data.pdf',
#  'The_Opportunity_Process_for_Optimal_Consumption_and_Investment_with_Power_Utility.pdf',
#  'Patterns_of_dominant_flows_in_the_world_trade_web.pdf',
#  'Financial_Market_Modeling_with_Quantum_Neural_Networks.pdf',
#  'La_Loi_organique_relative_aux_lois_de_finances_LOLF_dans_les_institutions_culturelles_publiques_du_spectacle_vivant_en_France.pdf',
#  'A_localization_of_the_L_e\xcc\x81_vy_operators_arising_in_mathematical_finances.pdf',
#  'An_Extension_to_Gaussian_Semigroup_and_Some_Applications.pdf',
#  'A_bright_future_for_financial_agent_based_models.pdf',
#  'Scaling_and_efficiency_determine_the_irreversible_evolution_of_a_market.pdf',
#  'Modelling_and_computer_simulation_of_an_insurance_policy_A_search_for_maximum_profit.pdf',
#  'Un_mode\xcc\x80le_boole\xcc\x81en_pour_l_e\xcc\x81nume\xcc\x81ration_des_siphons_et_des_pie\xcc\x80ges_minimaux_dans_les_re\xcc\x81seaux_de_Petri.pdf',
#  'Borges_Dilemma_Fundamental_Laws_and_Systems_Biology.pdf',
#  'Shortfall_Minimization_for_Game_Options_in_Discrete_Time.pdf',
#  'Topics_in_Stochastic_Portfolio_Theory.pdf',
#  'The_False_Premises_and_Promises_of_Bitcoin.pdf',
#  'Detecting_intraday_financial_market_states_using_temporal_clustering.pdf',
#  'The_Origin_of_Fat_Tails.pdf',
#  'The_Role_of_Rating_and_Loan_Characteristics_in_Online_Microfunding_Behaviors.pdf',
#  'Modelling_of_stock_price_changes_a_real_analysis_approach.pdf',
#  'The_Importance_of_Being_Discrete_Life_Always_Wins_on_the_Surface.pdf',
#  'The_Bowley_Ratio.pdf',
#  'Stochastic_volatility_and_leverage_effect.pdf',
#  'A_semi_quantitative_equivalence_for_abstracting_from_fast_reactions.pdf',
#  'Sequence_Length_Requirement_of_Distance_Based_Phylogeny_Reconstruction_Breaking_the_Polynomial_Barrier.pdf',
#  'Inconsistency_of_the_judgment_matrix_in_the_AHP_method_and_the_decision_maker_s_knowledge.pdf',
#  'Diffusion_Controlled_Reactions_Fluctuation_Dominated_Kinetics_and_Living_Cell_Biochemistry.pdf',
#  'Confidence_sets_in_nonparametric_calibration_of_exponential_Le\xcc\x81vy_models.pdf',
#  'Model_Risk_Analysis_via_Investment_Structuring.pdf',
#  'Graphical_models_for_correlated_defaults.pdf',
#  'AptaTRACE_Elucidating_Sequence_Structure_Binding_Motifs_by_Uncovering_Selection_Trends_in_HT_SELEX_Experiments.pdf',
#  'Econophysics_of_precious_stones.pdf',
#  'On_the_scaling_of_the_distribution_of_daily_price_fluctuations_in_Mexican_financial_market_index.pdf',
#  'L_utilisation_des_splines_bidimensionnels_pour_l_estimation_de_lois_de_maintien_en_arre\xcc\x82t_de_travail.pdf',
#  'Nonlinearity_in_stock_networks.pdf',
#  'Quantitative_analysis_of_privatization.pdf',
#  'Reversibility_and_Adiabatic_Computation_Trading_Time_and_Space_for_Energy.pdf',
#  'Asymmetric_statistics_of_order_books_The_role_of_discreteness_and_evidence_for_strategic_order_placement.pdf',
#  'Top_down_Paradigm_in_Engineering_Software_Integration.pdf',
#  'Exact_simulation_pricing_with_Gamma_processes_and_their_extensions.pdf',
#  'Volatility_made_observable_at_last.pdf',
#  'Optimal_Control_of_Stochastic_Functional_Differential_Equations_with_Application_to_Finance.pdf',
#  'Dynamic_Interaction_Between_Asset_Prices_and_Bank_Behavior_A_Systemic_Risk_Perspective.pdf',
#  'Quantitative_approach_to_multifractality_induced_by_correlations_and_broad_distribution_of_data.pdf',
#  'Fisher_information_and_quantum_mechanical_models_for_finance.pdf',
#  'Geometric_Arbitrage_Theory_and_Market_Dynamics.pdf',
#  'New_Approach_for_Prediction_Pre_cancer_via_Detecting_Mutated_in_Tumor_Protein_P53.pdf',
#  'Parameter_Identification_for_Markov_Models_of_Biochemical_Reactions.pdf',
#  'The_normaly_distributed_daily_returns_in_stock_trading.pdf',
#  'Moody_s_Correlated_Binomial_Default_Distributions_for_Inhomogeneous_Portfolios.pdf',
#  'Reverse_Engineering_of_Molecular_Networks_from_a_Common_Combinatorial_Approach.pdf',
#  'Dissection_of_Bitcoin_s_Multiscale_Bubble_History_from_January_2012_to_February_2018.pdf',
#  'A_mechanism_leading_bubbles_to_crashes_the_case_of_Japan_s_land_markets.pdf',
#  'Universal_Laws_and_Economic_Phenomena.pdf',
#  'CCP_Cleared_or_Bilateral_CSA_Trades_with_Initial_Variation_Margins_under_credit_funding_and_wrong_way_risks_A_Unified_Valuation_Approach.pdf',
#  'A_discontinuous_Galerkin_method_for_cohesive_zone_modelling.pdf',
#  'The_transposition_distance_for_phylogenetic_trees.pdf',
#  'A_compartmental_model_of_the_cAMP_PKA_MAPK_pathway_in_Bio_PEPA.pdf',
#  'Forward_equations_for_option_prices_in_semimartingale_models.pdf',
#  'Asymptotic_expansion_for_some_local_volatility_models_arising_in_finance.pdf',
#  'The_Exact_Smile_of_some_Local_Volatility_Models.pdf',
#  'Applications_of_physics_to_economics_and_finance_Money_income_wealth_and_the_stock_market.pdf',
#  'Impact_of_meta_order_in_the_Minority_Game.pdf',
#  'Quantitative_easing_is_an_incomplete_strategy_that_must_be_accompanied_by_the_nullification_of_debt.pdf',
#  'Standardised_Reputation_Measurement.pdf',
#  'Market_inefficiency_identified_by_both_single_and_multiple_currency_trends.pdf',
#  'Quantum_computing_for_finance_overview_and_prospects.pdf',
#  'A_transform_approach_to_compute_prices_and_greeks_of_barrier_options_driven_by_a_class_of_Levy_processes.pdf',
#  'The_Financing_of_Innovative_SMEs_a_multicriteria_credit_rating_model.pdf',
#  'Asset_asset_interactions_and_clustering_in_financial_markets.pdf',
#  'Some_Possible_Solution_of_Problem_of_Sovereign_Debts_a_short_plan.pdf',
#  'The_Evolution_of_Security_Prices_Is_Governed_by_a_Physicomathematical_Law.pdf',
#  'One_trade_at_a_time_unraveling_the_Equity_Premium_Puzzle.pdf',
#  'Fluctuation_analysis_of_the_three_agent_groups_herding_model.pdf',
#  'Robust_Utility_Maximization_with_Le\xcc\x81vy_Processes.pdf',
#  'A_Multi_Level_Lorentzian_Analysis_of_the_Basic_Structures_of_the_Daily_DJIA.pdf',
#  'Joint_Modelling_of_Gas_and_Electricity_spot_prices.pdf',
#  'Unique_Perfect_Phylogeny_Characterizations_via_Uniquely_Representable_Chordal_Graphs.pdf',
#  'Retarded_action_principle_and_self_financing_portfolio_dynamics.pdf',
#  'The_non_linear_trade_off_between_return_and_risk_a_regime_switching_multi_factor_framework.pdf',
#  'Study_of_a_model_for_the_distribution_of_wealth.pdf',
#  'Temporal_evolution_of_the_thermal_and_superthermal_income_classes_in_the_USA_during_1983_2001.pdf',
#  'A_quantitative_Balian_Low_theorem_for_higher_dimensions.pdf',
#  'Optimal_consumption_in_discrete_time_financial_models_with_industrial_investment_opportunities_and_nonlinear_returns.pdf',
#  'Reachability_in_Biochemical_Dynamical_Systems_by_Quantitative_Discrete_Approximation_extended_abstract.pdf',
#  'Efficient_and_accurate_log_Le\xcc\x81vy_approximations_to_Le\xcc\x81vy_driven_LIBOR_models.pdf',
#  'Combining_haplotypers.pdf',
#  'Optimal_portfolio_selection_and_compression_in_an_incomplete_market.pdf',
#  'Goodness_of_fit_of_the_Heston_model.pdf',
#  'Combined_Mutiplicative_Heston_Model_for_Stochastic_Volatility.pdf',
#  'Investigating_modularity_in_the_analysis_of_process_algebra_models_of_biochemical_systems.pdf',
#  'Visualizing_the_Invisible_Hand_of_Markets_Simulating_complex_dynamic_economic_interactions.pdf',
#  'Shaping_the_international_financial_system_in_century_of_globalization.pdf',
#  'Scaling_conditional_tail_probability_and_quantile_estimators.pdf',
#  'Quantum_Mechanics_Path_Integrals_and_Option_Pricing_Reducing_the_Complexity_of_Finance.pdf',
#  'The_Immune_System_the_ultimate_fractionated_cyber_physical_system.pdf',
#  'Optimal_Execution_Trajectories_Linear_Market_Impact_with_Exponential_Decay.pdf',
#  'Regulation_Simulation.pdf',
#  'Efficient_Parallel_Statistical_Model_Checking_of_Biochemical_Networks.pdf',
#  'Does_economics_need_a_scientific_revolution.pdf',
#  'Review_on_Feature_Selection_Techniques_and_the_Impact_of_SVM_for_Cancer_Classification_using_Gene_Expression_Profile.pdf',
#  'Economy_of_scales_in_R_D_with_block_busters.pdf',
#  'Measuring_capital_market_efficiency_Global_and_local_correlations_structure.pdf',
#  'Quantitative_comparisons_between_finitary_posterior_distributions_and_Bayesian_posterior_distributions.pdf',
#  'Econophysics_Empirical_facts_and_agent_based_models.pdf',
#  'How_sensitive_are_equilibrium_pricing_models_to_real_world_distortions.pdf',
#  'How_many_paths_to_simulate_correlated_Brownian_motions.pdf',
#  'Power_law_for_the_calm_time_interval_of_price_changes.pdf',
#  'Wavelet_Based_Volatility_Clustering_Estimation_of_Foreign_Exchange_Rates.pdf',
#  'On_Robustness_Analysis_of_Stochastic_Biochemical_Systems_by_Probabilistic_Model_Checking.pdf',
#  'Critical_Crashes.pdf',
#  'A_Novel_Combinatorial_Method_for_Estimating_Transcript_Expression_with_RNA_Seq_Bounding_the_Number_of_Paths.pdf',
#  'Pricing_Exotic_Options_in_a_Path_Integral_Approach.pdf',
#  'Embedded_Spreadsheet_Modelling.pdf',
#  'On_the_Interpretation_of_Delays_in_Delay_Stochastic_Simulation_of_Biological_Systems.pdf',
#  'Detrended_Cross_Correlation_Analysis_A_New_Method_for_Analyzing_Two_Non_stationary_Time_Series.pdf',
#  'Extrapolating_the_term_structure_of_interest_rates_with_parameter_uncertainty.pdf',
#  'A_characteristic_time_scale_of_tick_quotes_on_foreign_currency_markets.pdf',
#  'eXamine_Exploring_annotated_modules_in_networks.pdf',
#  'Detecting_Differential_Expression_from_RNA_seq_Data_with_Expression_Measurement_Uncertainty.pdf',
#  'Detecting_Superbubbles_in_Assembly_Graphs.pdf',
#  'An_optimization_strategy_on_prion_AGAAAAGA_amyloid_fibril_molecular_modeling.pdf',
#  'New_measure_of_multifractality_and_its_application_in_finances.pdf',
#  'Polynomial_Diffusions_and_Applications_in_Finance.pdf',
#  'A_Compact_Mathematical_Model_of_the_World_System_Economic_and_Demographic_Growth_1_CE_1973_CE.pdf',
#  'Deep_Supervised_and_Convolutional_Generative_Stochastic_Network_for_Protein_Secondary_Structure_Prediction.pdf',
#  'A_proposal_of_a_methodological_framework_with_experimental_guidelines_to_investigate_clustering_stability_on_financial_time_series.pdf',
#  'Quantifying_the_implicit_process_flow_abstraction_in_SBGN_PD_diagrams_with_Bio_PEPA.pdf',
#  'Pricing_and_hedging_game_options_in_currency_models_with_proportional_transaction_costs.pdf',
#  'A_Merton_Like_Approach_to_Pricing_Debt_based_on_a_non_Gaussian_Asset_Model.pdf',
#  'Biased_Roulette_Wheel_A_Quantitative_Trading_Strategy_Approach.pdf',
#  'The_price_impact_of_order_book_events_market_orders_limit_orders_and_cancellations.pdf',
#  'Study_on_optimal_timing_of_mark_to_market_for_contingent_credit_risk_control.pdf',
#  'Quantitative_Grothendieck_Property.pdf',
#  'On_Programs_and_Genomes.pdf',
#  'Capital_allocation_for_credit_portfolios_with_kernel_estimators.pdf',
#  'Composable_Languages_for_Bioinformatics_The_NYoSh_experiment.pdf',
#  'Utility_based_pricing_and_hedging_of_jump_diffusion_processes_with_a_view_to_applications.pdf',
#  'The_systematic_structure_and_predictability_of_urban_business_diversity.pdf',
#  'Statistical_mechanics_of_neocortical_interactions_Portfolio_of_Physiological_Indicators.pdf',
#  'Herding_behavior_in_cryptocurrency_markets.pdf',
#  'Explicit_solution_to_dynamic_portfolio_choice_problem_The_continuous_time_detour.pdf',
#  'Forecasting_stock_market_returns_over_multiple_time_horizons.pdf',
#  'An_empirical_study_of_the_tails_of_mutual_fund_size.pdf',
#  'Abstract_Interpretation_for_Probabilistic_Termination_of_Biological_Systems.pdf',
#  'Statistical_properties_of_information_flow_in_financial_time_series.pdf',
#  'Transitions_in_the_Stock_Markets_of_the_US_UK_and_Germany.pdf',
#  'Using_high_performance_computing_and_Monte_Carlo_simulation_for_pricing_american_options.pdf',
#  'The_US_2000_2002_Market_Descent_How_Much_Longer_and_Deeper.pdf',
#  'Removing_noise_from_correlations_in_multivariate_stock_price_data.pdf',
#  'Weak_Correlations_of_Stocks_Future_Returns.pdf',
#  'Application_of_Graph_Coloring_to_Biological_Networks.pdf',
#  'Discrete_Time_Quadratic_Hedging_of_Barrier_Options_in_Exponential_Le\xcc\x81vy_Model.pdf',
#  'Spectral_Sequence_Motif_Discovery.pdf',
#  'An_Efficient_Biological_Sequence_Compression_Technique_Using_LUT_And_Repeat_In_The_Sequence.pdf',
#  'Feature_Selection_for_Microarray_Gene_Expression_Data_using_Simulated_Annealing_guided_by_the_Multivariate_Joint_Entropy.pdf',
#  'The_Community_Structure_of_the_Global_Corporate_Network.pdf',
#  'Empirical_properties_of_the_variety_of_a_financial_portfolio_and_the_single_index_model.pdf',
#  'On_Designing_Multicore_aware_Simulators_for_Biological_Systems.pdf',
#  'Firms_Growth_Dynamics_Competition_and_Power_Law_Scaling.pdf',
#  'Importance_sampling_for_jump_processes_and_applications_to_finance.pdf',
#  'Five_Years_of_Continuous_time_Random_Walks_in_Econophysics.pdf',
#  'Computation_of_copulas_by_Fourier_methods.pdf',
#  'Asset_returns_and_volatility_clustering_in_financial_time_series.pdf',
#  'Unraveling_Spurious_Properties_of_Interaction_Networks_with_Tailored_Random_Networks.pdf',
#  'Fluctuation_scaling_versus_gap_scaling.pdf',
#  'Generalization_of_Doob_s_Inequality_and_A_Tighter_Estimate_on_Look_back_Option_Price.pdf',
#  'Machine_Learning_for_Integrating_Data_in_Biology_and_Medicine_Principles_Practice_and_Opportunities.pdf',
#  'Non_Parametric_Estimates_of_Option_Prices_Using_Superhedging.pdf',
#  'An_Algorithmic_Pipeline_for_Analyzing_Multi_parametric_Flow_Cytometry_Data.pdf',
#  'Quantitative_Factorization_of_weakly_compact_Rosenthal_and_\xce\xbe_Banach_Saks_operators.pdf',
#  'Multifractal_returns_and_Hierarchical_Portfolio_Theory.pdf',
#  'Structural_Learning_for_Template_free_Protein_Folding.pdf',
#  'Information_Percolation_Some_General_Cases_with_an_Application_to_Econophysics.pdf',
#  'K_means_and_Cluster_Models_for_Cancer_Signatures.pdf',
#  'The_quantitative_Morse_theorem.pdf',
#  'Correlation_structure_of_extreme_stock_returns.pdf',
#  'Monetary_value_measures_in_a_category_of_probability_spaces.pdf',
#  'Monte_Carlo_approximation_to_optimal_investment.pdf',
#  'The_leverage_effect_in_financial_markets_retarded_volatility_and_market_panic.pdf',
#  'Spurious_trend_switching_phenomena_in_financial_markets.pdf',
#  'Combustion_Models_in_Finance.pdf',
#  'ConocoPhillips_share_price_model_revisited.pdf',
#  'Transformation_methods_for_evaluating_approximations_to_the_optimal_exercise_boundary_for_linear_and_nonlinear_Black_Scholes_equations.pdf',
#  'Disease_processes_as_hybrid_dynamical_systems.pdf',
#  'Mining_Statistically_Significant_Substrings_using_the_Chi_Square_Statistic.pdf',
#  'Adaptive_Filter_Design_for_Stock_Market_Prediction_Using_a_Correlation_based_Criterion.pdf',
#  'BlenX_based_compositional_modeling_of_complex_reaction_mechanisms.pdf',
#  'On_the_Origin_of_Power_Law_Fluctuations_in_Stock_Prices.pdf',
#  'Monte_Carlo_modeling_of_the_effect_of_extreme_events_on_the_extinction_dynamics_of_animal_species_with_2_year_life_cycles.pdf',
#  'Asian_Option_Pricing_with_Orthogonal_Polynomials.pdf',
#  'From_Minority_Games_to_real_markets.pdf',
#  'A_Neural_Networks_Model_of_the_Venezuelan_Economy.pdf',
#  'Online_Portfolio_Selection_A_Survey.pdf',
#  'Analysis_Of_Cancer_Omics_Data_In_A_Semantic_Web_Framework.pdf',
#  'Generative_Models_for_Stochastic_Processes_Using_Convolutional_Neural_Networks.pdf',
#  'Risk_Management_Methods_for_the_Libor_Market_Model_Using_Semidefinite_Programming.pdf',
#  'Can_One_Make_Any_Crash_Prediction_in_Finance_Using_the_Local_Hurst_Exponent_Idea.pdf',
#  'Trading_networks_abnormal_motifs_and_stock_manipulation.pdf',
#  'Gene_selection_for_cancer_classification_using_a_hybrid_of_univariate_and_multivariate_feature_selection_methods.pdf',
#  'Effect_of_Volatility_Clustering_on_Indifference_Pricing_of_Options_by_Convex_Risk_Measures.pdf',
#  'Parameter_Synthesis_for_Cardiac_Cell_Hybrid_Models_Using_Delta_Decisions.pdf',
#  'Fluctuations_and_response_in_financial_markets_the_subtle_nature_of_random_price_changes.pdf',
#  'ADM_CLE_approach_for_detecting_slow_variables_in_continuous_time_Markov_chains_and_dynamic_data.pdf',
#  'Comparative_statistics_of_Garman_Klass_Parkinson_Roger_Satchell_and_bridge_estimators.pdf',
#  'American_Step_Up_and_Step_Down_Default_Swaps_under_Levy_Models.pdf',
#  'How_fast_does_the_clock_of_Finance_run_A_time_definition_enforcing_scale_invariance_and_quantifying_overnights.pdf',
#  'Theory_and_Applications_of_Robust_Optimization.pdf',
#  'Long_range_memory_and_multifractality_in_gold_markets.pdf',
#  'Income_Distribution_Dependence_of_Poverty_Measure_A_Theoretical_Analysis.pdf',
#  'Some_applications_and_methods_of_large_deviations_in_finance_and_insurance.pdf',
#  'Stock_Market_Market_Crash_of_2008_an_empirical_study_of_the_deviation_of_share_prices_from_company_fundamentals.pdf',
#  'First_Passage_Time_for_Multivariate_Jump_diffusion_Stochastic_Models_With_Applications_in_Finance.pdf',
#  'Projection_based_dimensionality_reduction_for_measure_valued_evolution_equations_in_statistical_manifolds.pdf',
#  'Fat_Tails_Quantified_and_Resolved_A_New_Distribution_to_Reveal_and_Characterize_the_Risk_and_Opportunity_Inherent_in_Leptokurtic_Data.pdf',
#  'Return_on_net_sales_from_three_companies_in_the_manufacturing_of_fabricated_metal_products_except_machinery_and_equipment.pdf',
#  'Stock_mechanics_unification_with_economy.pdf',
#  'Towards_a_microeconomic_theory_of_the_finance_driven_business_cycle.pdf',
#  'On_the_Risk_Management_with_Application_of_Econophysics_Analysis_in_Central_Banks_and_Financial_Institutions.pdf',
#  'An_Optimized_Data_Structure_for_High_Throughput_3D_Proteomics_Data_mzRTree.pdf',
#  'Large_scale_Machine_Learning_for_Metagenomics_Sequence_Classification.pdf',
#  'A_family_of_metrics_on_contact_structures_based_on_edge_ideals.pdf',
#  'Predicting_protein_contact_map_using_evolutionary_and_physical_constraints_by_integer_programming_extended_version.pdf',
#  'On_quantitative_Schur_and_Dunford_Pettis_properties.pdf',
#  'Ehrenfest_Model_with_Large_Jumps_in_Finance.pdf',
#  'PDBCirclePlot_A_Novel_Visualization_Method_for_Protein_Structures.pdf',
#  'Employing_functional_interactions_for_characterization_and_detection_of_sparse_complexes_from_yeast_PPI_networks.pdf',
#  'Picking_Winners_A_Data_Driven_Approach_to_Evaluating_the_Quality_of_Startup_Companies.pdf',
#  'Adjoints_and_Automatic_Algorithmic_Differentiation_in_Computational_Finance.pdf',
#  'Existence_uniqueness_and_global_regularity_for_degenerate_elliptic_obstacle_problems_in_mathematical_finance.pdf',
#  'Modeling_Vanilla_Option_prices_A_simulation_study_by_an_implicit_method.pdf',
#  'Volatility_is_rough.pdf',
#  'Constructing_a_genome_assembly_that_has_the_maximum_likelihood.pdf',
#  'A_simple_discretization_scheme_for_nonnegative_diffusion_processes_with_applications_to_option_pricing.pdf',
#  'Impact_of_the_Global_Crisis_on_SME_Internal_vs_External_Financing_in_China.pdf',
#  'Analysis_of_Financial_Credit_Risk_Using_Machine_Learning.pdf',
#  'Hawkes_processes_in_finance.pdf',
#  'Statistical_methods_for_tissue_array_images_algorithmic_scoring_and_co_training.pdf',
#  'Ranking_the_Economic_Importance_of_Countries_and_Industries.pdf',
#  'The_alchemy_of_probability_distributions_beyond_Gram_Charlier_expansions_and_a_skew_kurtotic_normal_distribution_from_a_rank_transmutation_map.pdf',
#  'Fractional_delta_hedging_strategy_for_pricing_currency_options_with_transaction_costs.pdf',
#  'Inverse_Reinforcement_Learning_for_Marketing.pdf',
#  'Research_on_fresh_agriculture_product_based_on_overconfidence_of_the_retailer_under_options_and_spot_markets_dominated.pdf',
#  'The_Convexity_of_the_Free_Boundary_for_the_American_put_option.pdf',
#  'Predictive_Comparative_QSAR_analysis_of_Sulfathiazole_Analogues_as_Mycobacterium_Tuberculosis_H37RV_Inhabitors.pdf',
#  'Py_oopsi_the_python_implementation_of_the_fast_oopsi_algorithm.pdf',
#  'Symmetries_of_the_Black_Scholes_equation.pdf',
#  'Fine_tune_your_smile_Correction_to_Hagan_et_al.pdf',
#  'A_Precursor_of_Market_Crashes.pdf',
#  'Roles_of_discount_rate_risk_premium_and_device_performance_in_estimating_the_cost_of_energy_for_photovoltaics.pdf',
#  'Genetic_Testing_for_Complex_Diseases_a_Simulation_Study_Perspective.pdf',
#  'Erratum_to_Yield_curve_shapes_and_the_asymptotic_short_rate_distribution_in_affine_one_factor_models.pdf',
#  'State_of_the_Art_Review_for_Applying_Computational_Intelligence_and_Machine_Learning_Techniques_to_Portfolio_Optimisation.pdf',
#  'Leveraging_User_Profile_and_Behaviour_to_Design_Practical_Spreadsheet_Controls_for_the_Finance_Function.pdf',
#  'Indexing_Finite_Language_Representation_of_Population_Genotypes.pdf',
#  'Market_dynamics_immediately_before_and_after_financial_shocks_quantifying_the_Omori_productivity_and_Bath_laws.pdf',
#  'Agent_based_model_with_multi_level_herding_for_complex_financial_systems.pdf',
#  'Survey_on_log_normally_distributed_market_technical_trend_data.pdf',
#  'Discontinuous_Galerkin_Deterministic_Solvers_for_a_Boltzmann_Poisson_Model_of_Hot_Electron_Transport_by_Averaged_Empirical_Pseudopotential_Band_Structures.pdf',
#  'Modelling_an_Ammonium_Transporter_with_SCLS.pdf',
#  'A_data_driven_model_order_reduction_approach_for_Stokes_flow_through_random_porous_media.pdf',
#  'Particle_Simulation_of_Fractional_Diffusion_Equations.pdf',
#  'Reference_Sequence_Construction_for_Relative_Compression_of_Genomes.pdf',
#  'Data_science_for_assessing_possible_tax_income_manipulation_The_case_of_Italy.pdf',
#  'A_New_Trinomial_Recombination_Tree_Algorithm_and_Its_Applications.pdf',
#  'Blind_source_separation_methods_for_deconvolution_of_complex_signals_in_cancer_biology.pdf',
#  'Lattice_model_refinement_of_protein_structures.pdf',
#  'Sticky_processes_local_and_true_martingales.pdf',
#  'Sum_of_all_Black_Scholes_Merton_models_An_efficient_pricing_method_for_spread_basket_and_Asian_options.pdf',
#  'Applying_hedging_strategies_to_estimate_model_risk_and_provision_calculation.pdf',
#  'Part_1_Training_Sets_ASG_Transforms.pdf',
#  'Quantitative_unique_continuation_of_solutions_to_higher_order_elliptic_equations_with_singular_coefficients.pdf',
#  'Near_optimal_estimation_of_jump_activity_in_semimartingales.pdf',
#  'Dual_Quantization_for_random_walks_with_application_to_credit_derivatives.pdf',
#  'Parallel_Simulations_for_Analysing_Portfolios_of_Catastrophic_Event_Risk.pdf',
#  'Dimension_Reduction_of_Large_AND_NOT_Network_Models.pdf',
#  'Dynamics_of_quasi_stationary_systems_Finance_as_an_example.pdf',
#  'A_Forward_Equation_for_Barrier_Options_under_the_Brunick_Shreve_Markovian_Projection.pdf',
#  'Opinion_Mining_for_Relating_Subjective_Expressions_and_Annual_Earnings_in_US_Financial_Statements.pdf',
#  'Market_shape_formation_statistical_equilibrium_and_neutral_evolution_theory.pdf',
#  'Error_estimates_for_binomial_approximations_of_game_put_options.pdf',
#  'Statistical_likelihood_methods_in_finance.pdf',
#  'Market_free_lunch_and_large_financial_markets.pdf',
#  'Dynamical_Stochastic_Processes_of_Returns_in_Financial_Markets.pdf',
#  'Scaling_in_the_Bombay_Stock_Exchange_Index.pdf',
#  'Global_modeling_of_transcriptional_responses_in_interaction_networks.pdf',
#  'A_physical_theory_of_economic_growth.pdf',
#  'Non_Randomness_Stock_Market_Price_Model_Amended.pdf',
#  'Consentaneous_agent_based_and_stochastic_model_of_the_financial_markets.pdf',
#  'Evolution_of_worldwide_stock_markets_correlation_structure_and_correlation_based_graphs.pdf',
#  'Option_Pricing_with_Orthogonal_Polynomial_Expansions.pdf',
#  'Accurate_Profiling_of_Microbial_Communities_from_Massively_Parallel_Sequencing_using_Convex_Optimization.pdf',
#  'Cross_comparison_and_modelling_of_Goldman_Sachs_Morgan_Stanley_JPMorgan_Chase_Bank_of_America_and_Franklin_Resources.pdf',
#  'Pricing_European_Options_by_Stable_Fourier_Cosine_Series_Expansions.pdf',
#  'A_New_Middle_Path_Approach_For_Alignements_In_Blast.pdf',
#  'On_the_American_swaption_in_the_linear_rational_framework.pdf',
#  'Flux_Analysis_in_Process_Models_via_Causality.pdf',
#  'Queueing_theoretical_analysis_of_foreign_currency_exchange_rates.pdf',
#  'Geometrical_Brownian_Motion_Driven_by_Color_Noise.pdf',
#  'Semimartingale_detection_and_goodness_of_fit_tests.pdf',
#  'Some_Contra_Arguments_for_the_Use_of_Stable_Distributions_in_Financial_Modeling.pdf',
#  'Calls_zonoids_peacocks_and_log_concavity.pdf',
#  'Quantitative_uniqueness_of_solutions_to_parabolic_equations.pdf',
#  'The_Hazards_of_Propping_Up_Bubbles_and_Chaos.pdf',
#  'SABCEMM_A_Simulation_Framework_for_Agent_Based_Computational_Economic_Market_Models.pdf',
#  'The_foreign_exchange_market_return_distributions_multifractality_anomalous_multifractality_and_Epps_effect.pdf',
#  'Memory_effects_in_stock_price_dynamics_evidences_of_technical_trading.pdf',
#  'Why_Quantitative_Structuring.pdf',
#  'Estimating_time_changes_in_noisy_Le\xcc\x81vy_models.pdf',
#  'Deterministic_criteria_for_the_absence_of_arbitrage_in_one_dimensional_diffusion_models.pdf',
#  'Pareto_law_and_Pareto_index_in_the_income_distribution_of_Japanese_companies.pdf',
#  'Gold_currencies_and_market_efficiency.pdf',
#  'From_Ecology_to_Finance_and_Back_Recent_Advancements_in_the_Analysis_of_Bipartite_Networks.pdf',
#  'Fossil_fuel_consumption_and_economic_growth_causality_relationship_in_the_world.pdf',
#  'A_General_Sensitivity_Analysis_Approach_for_Demand_Response_Optimizations.pdf',
#  'The_Bivariate_Normal_Copula.pdf',
#  'Design_and_Realization_of_a_Scalable_Simulator_of_Magnetic_Resonance_Tomography.pdf',
#  'A_Path_Integral_Approach_to_Derivative_Security_Pricing_I_Formalism_and_Analytical_Results.pdf',
#  'Faster_Algorithms_for_RNA_folding_using_the_Four_Russians_method.pdf',
#  'Asymptotic_Expansion_as_Prior_Knowledge_in_Deep_Learning_Method_for_high_dimensional_BSDEs.pdf',
#  'Protofold_II_Enhanced_Model_and_Implementation_for_Kinetostatic_Protein_Folding.pdf',
#  'Wavelet_Based_Prediction_for_Governance_Diversification_and_Value_Creation_Variables.pdf',
#  'Overview_of_utility_based_valuation.pdf',
#  'Disentangling_and_Assessing_Uncertainties_in_Multiperiod_Corporate_Default_Risk_Predictions.pdf',
#  'Local_Volatility_Calibration_by_Optimal_Transport.pdf',
#  'Optimal_Asset_Allocation_with_Asymptotic_Criteria.pdf',
#  'Fear_Universality_and_Doubt_in_Asset_price_movements.pdf',
#  'Early_warning_of_large_volatilities_based_on_recurrence_interval_analysis_in_Chinese_stock_markets.pdf',
#  'A_Model_of_the_Cellular_Iron_Homeostasis_Network_Using_Semi_Formal_Methods_for_Parameter_Space_Exploration.pdf',
#  'Imitation_and_contrarian_behavior_hyperbolic_bubbles_crashes_and_chaos.pdf',
#  'Statistical_properties_of_stock_order_books_empirical_results_and_models.pdf',
#  'A_Radial_Basis_Function_RBF_Finite_Difference_Method_for_the_Simulation_of_Reaction_Diffusion_Equations_on_Stationary_Platelets_within_the_Augmented_Forcing_Method.pdf',
#  'Indeterminacy_in_foreign_exchange_market.pdf',
#  'Natural_Selection_as_an_Inhibitor_of_Genetic_Diversity_Multiplicative_Weights_Updates_Algorithm_and_a_Conjecture_of_Haploid_Genetics.pdf',
#  'Protein_Multi_Location_Prediction_Using_Location_Inter_Dependencies_in_a_Probabilistic_Framework.pdf',
#  'Analysis_of_Barcode_sequence_features_to_find_anomalies_due_to_amplification_Bias.pdf',
#  'Predicting_stock_market_movements_using_network_science_An_information_theoretic_approach.pdf',
#  'Eigenvector_Synchronization_Graph_Rigidity_and_the_Molecule_Problem.pdf',
#  'Microeconomic_co_evolution_model_for_financial_technical_analysis_signals.pdf',
#  'Quantitative_law_describing_market_dynamics_before_and_after_interest_rate_change.pdf',
#  'Time_Scales_in_Futures_Markets_and_Applications.pdf',
#  'Fractional_processes_as_models_in_stochastic_finance.pdf',
#  'On_a_quantitative_operator_K_theory.pdf',
#  'Rational_Decision_Making_Under_Uncertainty_Observed_Betting_Patterns_on_a_Biased_Coin.pdf',
#  'Finite_element_scheme_for_integro_partial_differential_equations.pdf',
#  'CLP_based_protein_fragment_assembly.pdf',
#  'Anti_Robust_and_Tonsured_Statistics.pdf',
#  'A_Path_Integral_Approach_to_Derivative_Security_Pricing_II_Numerical_Methods.pdf',
#  'Non_linear_Time_Series_and_Artificial_Neural_Networks_of_Red_Hat_Volatility.pdf',
#  'Quantitative_relations_between_corruption_and_economic_factors.pdf',
#  'StochKit_FF_Efficient_Systems_Biology_on_Multicore_Architectures.pdf',
#  'Accurate_fully_automated_NMR_spectral_profiling_for_metabolomics.pdf',
#  'A_global_consumer_led_strategy_to_tackle_climate_change.pdf',
#  'An_explicit_solution_for_optimal_investment_in_Heston_model.pdf',
#  'Interest_Rates_and_Inflation.pdf',
#  'An_Application_of_Correlation_Clustering_to_Portfolio_Diversification.pdf',
#  'Optimal_detection_of_changepoints_with_a_linear_computational_cost.pdf',
#  'Biology_Derived_Algorithms_in_Engineering_Optimization.pdf',
#  'Pricing_joint_claims_on_an_asset_and_its_realized_variance_under_stochastic_volatility_models.pdf',
#  'UPDATE_February_2012_The_Food_Crises_Predictive_validation_of_a_quantitative_model_of_food_prices_including_speculators_and_ethanol_conversion.pdf',
#  'Multiple_output_support_vector_regression_with_a_firefly_algorithm_for_interval_valued_stock_price_index_forecasting.pdf',
#  'Additive_versus_multiplicative_parameters_applications_in_economics_and_finance.pdf',
#  'Stable_Feature_Selection_for_Biomarker_Discovery.pdf',
#  'Implied_Volatility_Surface_Construction_Methodologies_and_Characteristics.pdf',
#  'Predict_Forex_Trend_via_Convolutional_Neural_Networks.pdf',
#  'High_frequency_Cross_correlation_in_a_Set_of_Stocks.pdf',
#  'Kriging_Scenario_For_Capital_Markets.pdf',
#  'Density_analysis_of_non_Markovian_BSDEs_and_applications_to_biology_and_finance.pdf',
#  'CplexA_a_Mathematica_package_to_study_macromolecular_assembly_control_of_gene_expression.pdf',
#  'Efficient_Markets_Behavioral_Finance_and_a_Statistical_Evidence_of_the_Validity_of_Technical_Analysis.pdf',
#  'Null_Models_of_Economic_Networks_The_Case_of_the_World_Trade_Web.pdf',
#  'Necessary_Optimality_Condition_for_a_Discrete_Dead_Oil_Isotherm_Optimal_Control_Problem.pdf',
#  'Denoising_the_3_Base_Periodicity_Walks_of_DNA_Sequences_in_Gene_Finding.pdf',
#  'Inferring_Volatility_in_the_Heston_Model_and_its_Relatives_an_Information_Theoretical_Approach.pdf',
#  'MAIES_A_Tool_for_DNA_Mixture_Analysis.pdf',
#  'Description_of_the_Operational_Mechanics_of_a_Basel_Regulated_Banking_System.pdf',
#  'Advances_in_the_Biomedical_Applications_of_the_EELA_Project.pdf',
#  'Model_Uncertainty_Recalibration_and_the_Emergence_of_Delta_Vega_Hedging.pdf',
#  'Indexing_large_genome_collections_on_a_PC.pdf',
#  'The_endogenous_dynamics_of_markets_price_impact_and_feedback_loops.pdf',
#  'Risk_measures_with_non_Gaussian_fluctuations.pdf',
#  'Efficient_Computation_of_Optimal_Trading_Strategies.pdf',
#  'Empirical_Study_of_the_1_2_3_Trend_Indicator.pdf',
#  'Inverse_Statistics_for_Stocks_and_Markets.pdf',
#  'Robust_Quantitative_Comparative_Statics_for_a_Multimarket_Paradox.pdf',
#  'MassChroQ_A_versatile_tool_for_mass_spectrometry_quantification.pdf',
#  'SASeq_A_Selective_and_Adaptive_Shrinkage_Approach_to_Detect_and_Quantify_Active_Transcripts_using_RNA_Seq.pdf',
#  'Modeling_the_price_of_Bitcoin_with_geometric_fractional_Brownian_motion_a_Monte_Carlo_approach.pdf',
#  'Turbulence_and_finance.pdf',
#  'Qualitative_Modelling_via_Constraint_Programming_Past_Present_and_Future.pdf',
#  'Time_dependent_Heston_model.pdf',
#  'Factorial_Moments_in_Complex_Systems.pdf',
#  'Analysis_of_the_most_important_variables_which_determine_innovation_among_rural_entrepreneurs.pdf',
#  'Quantifying_and_Visualizing_Uncertainties_in_Molecular_Models.pdf',
#  'Behavioral_Finance_Option_Pricing_Formulas_Consistent_with_Rational_Dynamic_Asset_Pricing.pdf',
#  'Managing_large_scale_scientific_hypotheses_as_uncertain_and_probabilistic_data.pdf',
#  'An_Algorithmic_Approach_to_Non_self_financing_Hedging_in_a_Discrete_Time_Incomplete_Market.pdf',
#  'Unifying_Parsimonious_Tree_Reconciliation.pdf',
#  'A_win_win_monetary_policy_in_Canada.pdf',
#  'The_500_00_AAPL_close_Manipulation_or_hedging_A_quantitative_analysis.pdf',
#  'Information_theoretic_Interestingness_Measures_for_Cross_Ontology_Data_Mining.pdf',
#  'Fundamental_Factors_versus_Herding_in_the_2000_2005_US_Stock_Market_and_Prediction.pdf',
#  'No_arbitrage_implies_power_law_market_impact_and_rough_volatility.pdf',
#  'Optimal_stopping_via_deeply_boosted_backward_regression.pdf',
#  'Stock_Trading_via_Feedback_Control_Stochastic_Model_Predictive_or_Genetic.pdf',
#  'A_quantitative_obstruction_to_collapsing_surfaces.pdf',
#  'A_hybrid_approach_for_risk_assessment_of_loan_guarantee_network.pdf',
#  'Numerical_Simulation_of_Fecal_Coliform_Dynamics_in_Luruaco_Lake_Colombia.pdf',
#  'BioPreDyn_bench_benchmark_problems_for_kinetic_modelling_in_systems_biology.pdf',
#  'Gravity_Dual_for_Reggeon_Field_Theory_and_Non_linear_Quantum_Finance.pdf',
#  'Estimating_the_Algorithmic_Complexity_of_Stock_Markets.pdf',
#  'Christhin_Quantitative_Analysis_of_Thin_Layer_Chromatography.pdf',
#  'khmer_Working_with_Big_Data_in_Bioinformatics.pdf',
#  'Multivector_variate_distributions_An_application_in_Finance.pdf',
#  'Pricing_Financial_Derivatives_Subject_to_Counterparty_Risk_and_Credit_Value_Adjustment.pdf',
#  'Comment_partitionner_automatiquement_des_marches_ale\xcc\x81atoires_Avec_application_a\xcc\x80_la_finance_quantitative.pdf',
#  'Cubature_on_Wiener_space_pathwise_convergence.pdf',
#  'Quantitative_Fatou_Theorems_and_Uniform_Rectifiability.pdf',
#  'Testing_the_Gaussian_Copula_Hypothesis_for_Financial_Assets_Dependences.pdf',
#  'Assessing_Consistency_of_Consumer_Confidence_Data_using_Dynamic_Latent_Class_Analysis.pdf',
#  'Self_organized_critical_topology_of_stock_markets.pdf',
#  'Non_parametric_Determination_of_Real_Time_Lag_Structure_between_Two_Time_Series_the_Optimal_Thermal_Causal_Path_Method.pdf',
#  'Affine_processes_on_positive_semidefinite_matrices.pdf',
#  'On_the_valuation_of_compositions_in_Le\xcc\x81vy_term_structure_models.pdf',
#  'Optimization_of_Trading_Physics_Models_of_Markets.pdf',
#  'Feature_extraction_in_protein_sequences_classification_a_new_stability_measure.pdf',
#  'Significance_of_log_periodic_precursors_to_financial_crashes.pdf',
#  'Have_your_cake_and_eat_it_too_increasing_returns_while_lowering_large_risks.pdf',
#  'Two_Dimensional_Angle_of_Arrival_Estimation.pdf',
#  'Market_Coupling_as_the_Universal_Algorithm_to_Assess_Zonal_Divisions.pdf',
#  'Converting_a_Systems_Dynamic_Model_to_an_Agent_based_model_for_studying_the_Bicoid_morphogen_gradient_in_Drosophila_embryo.pdf',
#  'Econophysics_of_Macro_Finance_Local_Multi_fluid_Models_and_Surface_like_Waves_of_Financial_Variables.pdf',
#  'VaR_Efficient_Portfolios_for_a_Class_of_Super_and_Sub_Exponentially_Decaying_Assets_Return_Distributions.pdf',
#  'The_Local_Fractal_Properties_of_the_Financial_Time_Series_on_the_Polish_Stock_Exchange_Market.pdf',
#  'Obstacle_problem_for_Arithmetic_Asian_options.pdf',
#  'Homogeneous_Volatility_Bridge_Estimators.pdf',
#  'The_space_of_outcomes_of_semi_static_trading_strategies_need_not_be_closed.pdf',
#  'Biological_Computing_Fundamentals_and_Futures.pdf',
#  'Game_theoretic_dynamic_investment_model_with_incomplete_information_futures_contracts.pdf',
#  'Utility_maximization_for_L_e\xcc\x81_vy_switching_models.pdf',
#  'Economic_decision_making_application_of_the_theory_of_complex_systems.pdf',
#  'Critical_Influences_of_Particle_Size_and_Adhesion_on_the_Powder_Layer_Uniformity_in_Metal_Additive_Manufacturing.pdf',
#  'SMC_ABC_methods_for_the_estimation_of_stochastic_simulation_models_of_the_limit_order_book.pdf',
#  'Reduced_Order_Models_for_Pricing_European_and_American_Options_under_Stochastic_Volatility_and_Jump_Diffusion_Models.pdf',
#  'Contagious_Synchronization_and_Endogenous_Network_Formation_in_Financial_Networks.pdf',
#  'Modelling_Biochemical_Operations_on_RNA_Secondary_Structures.pdf',
#  'Universal_price_impact_functions_of_individual_trades_in_an_order_driven_market.pdf',
#  'Double_Cascade_Model_of_Financial_Crises.pdf',
#  'Stochastic_Block_Coordinate_Frank_Wolfe_Algorithm_for_Large_Scale_Biological_Network_Alignment.pdf',
#  'Path_Coalescence_in_Spatially_Correlated_Random_Walks.pdf',
#  'Big_Data_Challenges_in_Genome_Informatics.pdf',
#  'From_Nuclear_Reactions_to_High_Frequency_Trading_an_R_function_Approach.pdf',
#  'High_frequency_market_making_with_inventory_constraints_and_directional_bets.pdf',
#  'Immunophenotypes_of_Acute_Myeloid_Leukemia_From_Flow_Cytometry_Data_Using_Templates.pdf',
#  'Pricing_Derivatives_by_Path_Integral_and_Neural_Networks.pdf',
#  'On_a_multi_timescale_statistical_feedback_model_for_volatility_fluctuations.pdf',
#  'A_mixed_Monte_Carlo_and_PDE_variance_reduction_method_for_foreign_exchange_options_under_the_Heston_CIR_model.pdf',
#  'Periodic_power_spectrum_with_applications_in_detection_of_latent_periodicities_in_DNA_sequences.pdf',
#  'Identification_of_Atlas_models.pdf',
#  'Spectral_methods_for_volatility_derivatives.pdf',
#  'Risk_trading_network_topology_and_banking_regulation.pdf',
#  'Marginal_and_dependence_uncertainty_bounds_optimal_transport_and_sharpness.pdf',
#  'The_waiting_time_distribution_of_LIFFE_bond_futures.pdf',
#  'The_Minimal_Model_of_Financial_Complexity.pdf',
#  'Bernstein_processes_Euclidean_Quantum_Mechanics_and_Interest_Rate_Models.pdf',
#  'Comparison_of_numerical_and_analytical_approximations_of_the_early_exercise_boundary_of_the_American_put_option.pdf',
#  'The_Valuation_of_Clean_Spread_Options_Linking_Electricity_Emissions_and_Fuels.pdf',
#  'Valuing_FtD_Contract_under_Copula_Approach_via_Monte_Carlo_Stimulation.pdf',
#  'Polish_and_Silesian_Non_Profit_Organizations_Liquidity_Strategies.pdf',
#  'Error_calculus_and_path_sensitivity_in_financial_models.pdf',
#  'Analyzing_Chromatin_Using_Tiled_Binned_Scatterplot_Matrices.pdf',
#  'RQA_Application_for_the_Monitoring_of_Financial_and_Commodity_markets_state.pdf',
#  'Spectrum_Identification_using_a_Dynamic_Bayesian_Network_Model_of_Tandem_Mass_Spectra.pdf',
#  'WeSME_Uncovering_Mutual_Exclusivity_of_Cancer_Drivers_and_Beyond.pdf',
#  'Bayesian_analysis_of_redistribution_policy_with_a_fixed_scale.pdf',
#  'Advertising_effects_in_Sznajd_marketing_model.pdf',
#  'The_Epps_effect_revisited.pdf',
#  'Biospectrogram_a_tool_for_spectral_analysis_of_biological_sequences.pdf',
#  'Technical_Report_CSVM_Ecosystem.pdf',
#  'What_are_the_main_drivers_of_the_Bitcoin_price_Evidence_from_wavelet_coherence_analysis.pdf',
#  'Self_Financing_Replicating_Hedging_Strategies_an_incomplete_thermodynamic_analogy.pdf',
#  'Correlation_based_networks_of_equity_returns_sampled_at_different_time_horizons.pdf',
#  'Preliminaries_to_an_investigation_of_reduced_product_set_finance.pdf',
#  'Re\xcc\x81flexions_sur_la_question_fre\xcc\x81quentielle_en_traitement_du_signal.pdf',
#  'Secular_bipolar_growth_rate_of_the_real_US_GDP_per_capita_implications_for_understanding_past_and_future_economic_growth.pdf',
#  'Navigating_in_a_sea_of_repeats_in_RNA_seq_without_drowning.pdf',
#  'No_Stable_Distributions_in_Finance_please.pdf',
#  'Compression_ratios_based_on_the_Universal_Similarity_Metric_still_yield_protein_distances_far_from_CATH_distances.pdf',
#  'A_simple_microstructure_return_model_explaining_microstructure_noise_and_Epps_effects.pdf',
#  'Speculative_bubbles_and_crashes_in_stock_market_an_interacting_agent_model_of_speculative_activity.pdf',
#  'Continuously_monitored_barrier_options_under_Markov_processes.pdf',
#  'Making_and_Evaluating_Point_Forecasts.pdf',
#  'An_Ontology_Based_Dialogue_Management_System_for_Banking_and_Finance_Dialogue_Systems.pdf',
#  'Dirac_Processes_and_Default_Risk.pdf',
#  'Filling_the_gaps_smoothly.pdf',
#  'Statistical_Properties_of_Share_Volume_Traded_in_Financial_Markets.pdf',
#  'Portfolio_Selection_with_Probabilistic_Utility_Bayesian_Statistics_and_Markov_Chain_Monte_Carlo.pdf',
#  'MOLNs_A_cloud_platform_for_interactive_reproducible_and_scalable_spatial_stochastic_computational_experiments_in_systems_biology_using_PyURDME.pdf',
#  'Novel_Modulation_Techniques_using_Isomers_as_Messenger_Molecules_for_Molecular_Communication_via_Diffusion.pdf',
#  'Obstacle_problems_for_nonlocal_operators.pdf',
#  'A_Space_Efficient_Approach_towards_Distantly_Homologous_Protein_Similarity_Searches.pdf',
# ...
#  'Trend_arbitrage_bid_ask_spread_and_market_dynamics.pdf',
#  'Effects_of_delayed_immune_response_in_tumor_immune_system_interplay.pdf',
#  'Duality_and_optimality_conditions_in_stochastic_optimization_and_mathematical_finance.pdf',
#  'Tracing_the_temporal_evolution_of_clusters_in_a_financial_stock_market.pdf',
#  'Customer_Selection_Model_with_Grouping_and_Hierarchical_Ranking_Analysis.pdf',
#  'Deterministic_Criteria_for_the_Absence_and_Existence_of_Arbitrage_in_Multi_Dimensional_Diffusion_Markets.pdf',
#  'Convex_Hedging_in_Incomplete_Markets.pdf',
#  'Superstatistics_of_Labour_Productivity_in_Manufacturing_and_Nonmanufacturing_Sectors.pdf',
#  'Microbial_community_pattern_detection_in_human_body_habitats_via_ensemble_clustering_framework.pdf',
#  'Copula_based_Hierarchical_Aggregation_of_Correlated_Risks_The_behaviour_of_the_diversification_benefit_in_Gaussian_and_Lognormal_Trees.pdf',
#  'Exploring_the_predictability_of_range_based_volatility_estimators_using_RNNs.pdf',
#  'Parameter_identification_in_large_kinetic_networks_with_BioPARKIN.pdf',
#  'The_general_mixture_diffusion_SDE_and_its_relationship_with_an_uncertain_volatility_option_model_with_volatility_asset_decorrelation.pdf',
#  'Robust_calibration_and_arbitrage_free_interpolation_of_SSVI_slices.pdf',
#  'Minimizing_the_Probability_of_Ruin_in_Retirement.pdf',
#  'Polynomial_Jump_Diffusion_Models.pdf',
#  'Multiple_graph_regularized_protein_domain_ranking.pdf',
#  'On_incompleteness_of_bond_markets_with_infinite_number_of_random_factors.pdf',
#  'WinBioinfTools_Bioinformatics_Tools_for_Windows_High_Performance_Computing_Server_2008.pdf',
#  'An_Introduction_to_Hedge_Funds.pdf',
#  'Modelling_financial_markets_by_the_multiplicative_sequence_of_trades.pdf',
#  'Time_consistency_of_dynamic_risk_measures_in_markets_with_transaction_costs.pdf',
#  'ClusCo_clustering_and_comparison_of_protein_models.pdf',
#  'SPDE_limit_of_the_global_fluctuations_in_rank_based_models.pdf',
#  'Stock_Price_Clustering_and_Discreteness_The_Compass_Rose_and_Predictability.pdf',
#  'Extended_master_equation_models_for_molecular_communication_networks.pdf',
#  'Predicting_RNA_Secondary_Structures_with_Arbitrary_Pseudoknots_by_Maximizing_the_Number_of_Stacking_Pairs.pdf',
#  'Computation_of_vector_sublattices_and_minimal_lattice_subspaces_of_R_k_Applications_in_finance.pdf',
#  'Simulation_of_Molecular_Signaling_in_Blood_Vessels_Software_Design_and_Application_to_Atherogenesis.pdf',
#  'A_Fixed_Parameter_Algorithm_for_Minimum_Common_String_Partition_with_Few_Duplications.pdf',
#  'Empirical_Distributions_of_Log_Returns_between_the_Stretched_Exponential_and_the_Power_Law.pdf',
#  'A_note_on_estimating_stochastic_volatility_and_its_volatility_a_new_simple_method.pdf',
#  'Analysis_of_trade_packages_in_Chinese_stock_market.pdf',
#  'A_Probability_Density_Function_for_Google_s_stocks.pdf',
#  'To_sigmoid_based_functional_description_of_the_volatility_smile.pdf',
#  'FX_Options_in_Target_Zone.pdf',
#  'Default_Contagion_with_Domino_Effect_A_First_Passage_Time_Approach.pdf',
#  'Moving_averages_and_markets_inefficiency.pdf',
#  'An_age_structured_demographic_theory_of_technological_change.pdf',
#  'Impact_Analysis_for_Risks_in_Informatics_Systems.pdf',
#  'Parallel_STEPS_Large_Scale_Stochastic_Spatial_Reaction_Diffusion_Simulation_with_High_Performance_Computers.pdf',
#  'Path_Integral_and_Asset_Pricing.pdf',
#  'An_Adaptive_Markov_Chain_Monte_Carlo_Method_for_GARCH_Model.pdf',
#  'What_is_the_Sharpe_Ratio_and_how_can_everyone_get_it_wrong.pdf',
#  'CANA_A_python_package_for_quantifying_control_and_canalization_in_Boolean_Networks.pdf',
#  'Entrainment_in_the_Master_Equation.pdf',
#  'Fragmentation_trees_reloaded.pdf',
#  'Hierarchy_of_protein_loop_lock_structures_a_new_server_for_the_decomposition_of_a_protein_structure_into_a_set_of_closed_loops.pdf',
#  'Arbitrage_Free_Interpolation_in_Models_of_Market_Observable_Interest_Rates.pdf',
#  'Gauge_theory_of_Finance.pdf',
#  'Dynamic_Conic_Finance_Pricing_and_Hedging_in_Market_Models_with_Transaction_Costs_via_Dynamic_Coherent_Acceptability_Indices.pdf',
#  'Heat_kernel_methods_in_finance_the_SABR_model.pdf',
#  'Volatility_Dynamics_of_Wavelet_Filtered_Stock_Prices.pdf',
#  'Statistical_Properties_of_Fluctuations_A_Method_to_Check_Market_Behavior.pdf',
#  'Tremor_price_dynamics_in_the_world_s_network_of_stock_exchanges.pdf',
#  'Probabilistic_analysis_of_the_human_transcriptome_with_side_information.pdf',
#  'An_example_of_short_term_relative_arbitrage.pdf',
#  'Multi_dimensional_Rational_Bubbles_and_fat_tails_application_of_stochastic_regression_equations_to_financial_speculation.pdf',
#  'Power_law_for_ensembles_of_stock_prices.pdf',
#  'A_Theory_of_Non_Gaussian_Option_Pricing.pdf',
#  'Quantum_Duality_in_Mathematical_Finance.pdf',
#  'Methods_and_Concepts_in_Economic_Complexity.pdf',
#  'Coupling_Importance_Sampling_and_Multilevel_Monte_Carlo_using_Sample_Average_Approximation.pdf',
#  'Weakly_nonlinear_analysis_of_the_Hamilton_Jacobi_Bellman_equation_arising_from_pension_savings_management.pdf',
#  'Productivity_Dispersion_Facts_Theory_and_Implications.pdf',
#  'A_Quantum_Approach_to_Stock_Price_Fluctuations.pdf',
#  'The_individual_income_distribution_in_Argentina_in_the_period_2000_2009_A_unique_source_of_non_stationary_data.pdf',
#  'Financial_Time_Series_Stylized_Facts_for_the_Mexican_Stock_Exchange_Index_Compared_to_Developed_Markets.pdf',
#  'Quantitative_ergodic_theorems_for_weakly_integrable_functions.pdf',
#  'An_Agent_based_Model_of_Contagion_in_Financial_Networks.pdf',
#  'Censored_Exploration_and_the_Dark_Pool_Problem.pdf',
#  'Efficient_Algorithms_for_de_novo_Assembly_of_Alternative_Splicing_Events_from_RNA_seq_Data.pdf',
#  'On_refined_volatility_smile_expansion_in_the_Heston_model.pdf',
#  'Reality_check_for_Econophysics_Likelihood_based_fitting_of_physics_inspired_market_models_to_empirical_data.pdf',
#  'Random_cascade_model_in_the_limit_of_infinite_integral_scale_as_the_exponential_of_a_non_stationary_1_f_noise_Application_to_volatility_fluctuations_in_stock_markets.pdf',
#  'Finance_Without_Probabilistic_Prior_Assumptions.pdf',
#  'MPDATA_Meets_Black_Scholes_Derivative_Pricing_as_a_Transport_Problem.pdf',
#  'No_Arbitrage_Pricing_for_Dividend_Paying_Securities_in_Discrete_Time_Markets_with_Transaction_Costs.pdf',
#  'Agent_based_Versus_Macroscopic_Modeling_of_Competition_and_Business_Processes_in_Economics_and_Finance.pdf',
#  'A_Non_commutative_Version_of_the_Fundamental_Theorem_of_Asset_Pricing.pdf',
#  'Applications_of_Machine_Learning_Methods_to_Quantifying_Phenotypic_Traits_that_Distinguish_the_Wild_Type_from_the_Mutant_Arabidopsis_Thaliana_Seedlings_during_Root_Gravitropism.pdf',
#  'Probability_distribution_of_returns_in_the_Heston_model_with_stochastic_volatility.pdf',
#  'The_role_of_distances_in_the_World_Trade_Web.pdf',
#  'GPGPUs_in_computational_finance_Massive_parallel_computing_for_American_style_options.pdf',
#  'Absolute_Return_Volatility.pdf',
#  'FIEMS_Fast_Italian_Energy_Market_Simulator.pdf',
#  'Hierarchical_information_clustering_by_means_of_topologically_embedded_graphs.pdf',
#  'Copula_Based_Univariate_Time_Series_Structural_Shift_Identification_Test.pdf',
#  'A_quantitative_version_of_the_Blow_up_Lemma.pdf',
#  'Physicists_attempt_to_scale_the_ivory_towers_of_finance.pdf',
#  'An_application_of_Malliavin_Calculus_to_Finance.pdf',
#  'Labour_Productivity_Superstatistics.pdf',
#  'Relativistic_Quantum_Finance.pdf',
#  'Quantitative_Stability_Estimate_of_the_Hardy_Littlewood_Functional_Under_Constraints.pdf',
#  'On_the_rates_of_convergence_of_simulation_based_optimization_algorithms_for_optimal_stopping_problems.pdf',
#  'Risk_Measures_in_Quantitative_Finance.pdf',
#  'Multiscale_Bone_Remodelling_with_Spatial_P_Systems.pdf',
#  'Pathwise_super_replication_via_Vovk_s_outer_measure.pdf',
#  'Behavioral_Finance_Asset_Prices_Predictability_Equity_Premium_Puzzle_Volatility_Puzzle_The_Rational_Finance_Approach.pdf',
#  'Effects_of_regulation_on_a_self_organized_market.pdf',
#  'Arbitrage_strategy.pdf',
#  'Filtrations.pdf',
#  'The_solution_of_discretionary_stopping_problems_with_applications_to_the_optimal_timing_of_investment_decisions.pdf',
#  'The_Nasdaq_crash_of_April_2000_Yet_another_example_of_log_periodicity_in_a_speculative_bubble_ending_in_a_crash.pdf',
#  'Modeling_the_non_Markovian_non_stationary_scaling_dynamics_of_financial_markets.pdf',
#  'Large_losses_probability_minimizing_approach.pdf',
#  'Stochastic_Calculus_of_Wrapped_Compartments.pdf',
#  'The_Relationship_Between_Stock_Market_Parameters_and_Interbank_Lending_Market_an_Empirical_Evidence.pdf',
#  'Presentation_Du_Nouvel_Accord_De_Bale_Sur_Les_Fonds_Propres.pdf',
#  'Arbitrage_Free_Pricing_Of_Derivatives_In_Nonlinear_Market_Models.pdf',
#  'The_CCI30_Index.pdf',
#  'Computing_Petaflops_over_Terabytes_of_Data_The_Case_of_Genome_Wide_Association_Studies.pdf',
#  'Estimation_of_Zero_Intelligence_Models_by_L1_Data.pdf',
#  'Discovering_Patterns_in_Biological_Sequences_by_Optimal_Segmentation.pdf',
#  'The_Statistical_Mechanics_of_Human_Weight_Change.pdf',
#  'Dynamics_of_a_financial_market_index_after_a_crash.pdf',
#  'The_Exponent_Expansion_An_Effective_Approximation_of_Transition_Probabilities_of_Diffusion_Processes_and_Pricing_Kernels_of_Financial_Derivatives.pdf',
#  'Protein_Inference_and_Protein_Quantification_Two_Sides_of_the_Same_Coin.pdf',
#  'Le\xcc\x81vy_Processes_For_Finance_An_Introduction_In_R.pdf',
#  'VESICLE_Volumetric_Evaluation_of_Synaptic_Interfaces_using_Computer_vision_at_Large_Scale.pdf',
#  'The_Economic_Mobility_in_Money_Transfer.pdf',
#  'High_order_splitting_schemes_with_complex_timesteps_and_their_application_in_mathematical_finance.pdf',
#  'On_the_new_central_bank_strategy_toward_monetary_and_financial_instabilities_management_in_finances_Econophysical_analysis_of_nonlinear_dynamical_financial_systems.pdf',
#  'The_Quantitative_Relations_between_Stock_Prices_and_Quantities_of_Tradable_Stock_Shares_and_Its_Applications.pdf',
#  'Random_Matrix_Filtering_in_Portfolio_Optimization.pdf',
#  'Volatilities_That_Change_with_Time_The_Temporal_Behavior_of_the_Distribution_of_Stock_Market_Prices.pdf',
#  'Will_solid_state_drives_accelerate_your_bioinformatics_In_depth_profiling_performance_analysis_and_beyond.pdf',
#  'An_Empirical_Method_to_Measure_Stochasticity_and_Multifractality_in_Nonlinear_Time_Series.pdf',
#  'Particle_methods_enable_fast_and_simple_approximation_of_Sobolev_gradients_in_image_segmentation.pdf',
#  'Stochastic_programs_without_duality_gaps.pdf',
#  'Signal_and_Noise_in_Correlation_Matrix.pdf',
#  'A_New_Kind_of_Finance.pdf',
#  'Particle_based_simulations_of_reaction_diffusion_processes_with_Aboria.pdf',
#  'Classical_and_quantum_randomness_and_the_financial_market.pdf',
#  'Activatability_for_simulation_tractability_of_NP_problems_Application_to_Ecology.pdf',
#  'A_Taxonomy_of_Causality_Based_Biological_Properties.pdf',
#  'Backward_Stochastic_Differential_Equations_and_Feynman_Kac_Formula_for_Multidimensional_Le\xcc\x81vy_Processes_with_Applications_in_Finance.pdf',
#  'Optimal_Hedging_for_Fund_Insurance_Managers_with_Partially_Observable_Investment_Flows.pdf',
#  'To_the_problem_of_turbulence_in_quantitative_easing_transmission_channels_and_transactions_network_channels_at_quantitative_easing_policy_implementation_by_central_banks.pdf',
#  'Statistical_Mechanics_of_Money_Income_and_Wealth_A_Short_Survey.pdf',
#  'Insights_in_Economical_Complexity_in_Spain_the_hidden_boost_of_migrants_in_international_tradings.pdf',
#  'True_random_numbers_from_amplified_quantum_vacuum.pdf',
#  'A_Critical_Survey_of_Deconvolution_Methods_for_Separating_cell_types_in_Complex_Tissues.pdf',
#  'Hawkes_process_model_with_a_time_dependent_background_rate_and_its_application_to_high_frequency_financial_data.pdf',
#  'Nonstationary_Increments_Scaling_Distributions_and_Variable_Diffusion_Processes_in_Financial_Markets.pdf',
#  'Feature_extraction_from_complex_networks_A_case_of_study_in_genomic_sequences_classification.pdf',
#  'A_Bayesian_Framework_for_Combining_Valuation_Estimates.pdf',
#  'Identification_of_cross_and_autocorrelations_in_time_series_within_an_approach_based_on_Wigner_eigenspectrum_of_random_matrices.pdf',
#  'Hidden_Fluid_Mechanics_A_Navier_Stokes_Informed_Deep_Learning_Framework_for_Assimilating_Flow_Visualization_Data.pdf',
#  'A_primer_on_reflexivity_and_price_dynamics_under_systemic_risk.pdf',
#  'On_the_multifractal_effects_generated_by_monofractal_signals.pdf',
#  'Identification_of_functionally_related_enzymes_by_learning_to_rank_methods.pdf',
#  'The_Social_Architecture_of_Capitalism.pdf',
#  'Non_Randomness_Stock_Market_Price_Model.pdf',
#  'Currency_target_zone_modeling_An_interplay_between_physics_and_economics.pdf',
#  'Modeling_of_the_contrast_enhanced_perfusion_test_in_liver_based_on_the_multi_compartment_flow_in_porous_media.pdf',
#  'Efficient_Discretization_of_Stochastic_Integrals.pdf',
#  'Approximated_Computation_of_Belief_Functions_for_Robust_Design_Optimization.pdf',
#  'Stochastic_PDEs_and_Quantitative_Finance_The_Black_Scholes_Merton_Model_of_Options_Pricing_and_Riskless_Trading.pdf',
#  'Impact_of_Artificial_Intelligence_on_Economic_Theory.pdf',
#  'Anticorrelations_and_subdiffusion_in_financial_systems.pdf',
#  'Inverse_Statistics_in_Economics_The_gain_loss_asymmetry.pdf',
#  'Types_for_BioAmbients.pdf',
#  'A_Theory_for_Market_Impact_How_Order_Flow_Affects_Stock_Price.pdf',
#  'Matching_Startup_Founders_to_Investors_a_Tool_and_a_Study.pdf',
#  'Stochastic_relaxational_dynamics_applied_to_finance_towards_non_equilibrium_option_pricing_theory.pdf',
#  'GPU_powered_Simulation_Methodologies_for_Biological_Systems.pdf',
#  'Exploiting_network_topology_for_large_scale_inference_of_nonlinear_reaction_models.pdf',
#  'Analysis_of_Kelly_optimal_portfolios.pdf',
#  'A_Possibilistic_and_Probabilistic_Approach_to_Precautionary_Saving.pdf',
#  'Semi_analytic_path_integral_solution_of_SABR_and_Heston_equations_pricing_Vanilla_and_Asian_options.pdf',
#  'Computer_simulations_reveal_complex_distribution_of_haemodynamic_forces_in_a_mouse_retina_model_of_angiogenesis.pdf',
#  'Power_laws_in_economy_and_finance_some_ideas_from_physics.pdf',
#  'Diffusive_behavior_and_the_modeling_of_characteristic_times_in_limit_order_executions.pdf',
#  'Goodness_of_fit_testing_for_the_Cauchy_distribution_with_application_to_financial_modeling.pdf',
#  'A_Study_of_the_PDGF_Signaling_Pathway_with_PRISM.pdf',
#  'Stochastic_Differential_Games_in_a_Non_Markovian_Setting.pdf',
#  'On_the_Matrix_Median_Problem.pdf',
#  'CryptoRuble_From_Russia_with_Love.pdf',
#  'Scale_free_effects_in_world_currency_exchange_network.pdf',
#  'Target_volatility_option_pricing_in_lognormal_fractional_SABR_model.pdf',
#  'Quantum_Game_Theory_in_Finance.pdf',
#  'Derivatives_pricing_using_signature_payoffs.pdf',
#  'Deriving_Derivatives.pdf',
#  'RPA_Probabilistic_analysis_of_probe_performance_and_robust_summarization.pdf',
#  'TripNet_A_Method_for_Constructing_Phylogenetic_Networks_from_Triplets.pdf',
#  'Multivariate_Integral_Perturbation_Techniques_I_Theory.pdf',
#  'Performance_of_information_criteria_used_for_model_selection_of_Hawkes_process_models_of_financial_data.pdf',
#  'Active_network_management_for_electrical_distribution_systems_problem_formulation_benchmark_and_approximate_solution.pdf',
#  'Stochastic_Volatility_in_a_Quantitative_Model_of_Stock_Market_Returns.pdf',
#  'Generalized_Subjective_Lexicographic_Expected_Utility_Representation.pdf',
#  'Generating_virtual_scenarios_of_multivariate_financial_data_for_quantitative_trading_applications.pdf',
#  'Phynance.pdf',
#  'Statistical_Properties_of_Statistical_Ensembles_of_Stock_Returns.pdf',
#  'Monte_Carlo_Simulations_of_the_First_Passage_Time_for_Multivariate_Jump_Diffusion_Processes_in_Financial_Applications.pdf',
#  'Symmetric_thermal_optimal_path_and_time_dependent_lead_lag_relationship_Novel_statistical_tests_and_application_to_UK_and_US_real_estate_and_monetary_policies.pdf',
#  'Drawdown_From_Practice_to_Theory_and_Back_Again.pdf',
#  'Fractional_calculus_and_continuous_time_finance.pdf',
#  'A_mathematical_proof_of_the_existence_of_trends_in_financial_time_series.pdf',
#  'Ito\xcc\x82_s_formula_for_finite_variation_Le\xcc\x81vy_processes_The_case_of_non_smooth_functions.pdf',
#  ...]

# %%
l = len(os.listdir('./papers'))
for i, f in enumerate(os.listdir('./papers')):
    renamed = f.split('.')[0] + '.txt'
    try:
        ! pdf2txt.py -o ./extracted_papers/{renamed} ./papers/{f}
    except:
        print(f)
    print(str(i)+'/'+str(l))
# Out:
# 0/1012
# 1/1012
# 2/1012
# 3/1012
# 4/1012
# 5/1012
# 6/1012
# 7/1012
# 8/1012
# 9/1012
# 10/1012
# 11/1012
# 12/1012
# 13/1012
# 14/1012
# 15/1012
# 16/1012
# 17/1012
# 18/1012
# 19/1012
# 20/1012
# 21/1012
# 22/1012
# 23/1012
# 24/1012
# 25/1012
# 26/1012
# 27/1012
# 28/1012
# 29/1012
# 30/1012
# 31/1012
# 32/1012
# 33/1012
# 34/1012
# 35/1012
# 36/1012
# 37/1012
# 38/1012
# 39/1012
# 40/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 41/1012
# 42/1012
# 43/1012
# 44/1012
# 45/1012
# 46/1012
# 47/1012
# 48/1012
# 49/1012
# 50/1012
# 51/1012
# 52/1012
# 53/1012
# 54/1012
# 55/1012
# 56/1012
# 57/1012
# 58/1012
# 59/1012
# 60/1012
# 61/1012
# 62/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 63/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 64/1012
# 65/1012
# 66/1012
# 67/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 110, in main
#     interpreter.process_page(page)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfinterp.py", line 839, in process_page
#     self.render_contents(page.resources, page.contents, ctm=ctm)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfinterp.py", line 850, in render_contents
#     self.init_resources(resources)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfinterp.py", line 356, in init_resources
#     self.fontmap[fontid] = self.rsrcmgr.get_font(objid, spec)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfinterp.py", line 195, in get_font
#     font = PDFCIDFont(self, spec)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdffont.py", line 674, in __init__
#     self.unicode_map = ttf.create_unicode_map()
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdffont.py", line 445, in create_unicode_map
#     assert 0
# AssertionError
# 68/1012
# 69/1012
# 70/1012
# 71/1012
# 72/1012
# 73/1012
# 74/1012
# 75/1012
# 76/1012
# 77/1012
# 78/1012
# 79/1012
# 80/1012
# 81/1012
# 82/1012
# 83/1012
# 84/1012
# 85/1012
# 86/1012
# 87/1012
# 88/1012
# 89/1012
# 90/1012
# 91/1012
# 92/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 93/1012
# 94/1012
# 95/1012
# 96/1012
# 97/1012
# 98/1012
# 99/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 100/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 101/1012
# 102/1012
# 103/1012
# 104/1012
# 105/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 106/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 107/1012
# 108/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 109/1012
# 110/1012
# 111/1012
# 112/1012
# 113/1012
# 114/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 115/1012
# 116/1012
# 117/1012
# 118/1012
# 119/1012
# 120/1012
# 121/1012
# 122/1012
# 123/1012
# 124/1012
# 125/1012
# 126/1012
# 127/1012
# 128/1012
# 129/1012
# 130/1012
# 131/1012
# 132/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 133/1012
# 134/1012
# 135/1012
# 136/1012
# 137/1012
# 138/1012
# 139/1012
# 140/1012
# 141/1012
# 142/1012
# 143/1012
# 144/1012
# 145/1012
# 146/1012
# 147/1012
# 148/1012
# 149/1012
# 150/1012
# 151/1012
# 152/1012
# 153/1012
# 154/1012
# 155/1012
# 156/1012
# 157/1012
# 158/1012
# 159/1012
# 160/1012
# 161/1012
# 162/1012
# 163/1012
# 164/1012
# 165/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 166/1012
# 167/1012
# 168/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 169/1012
# 170/1012
# 171/1012
# 172/1012
# 173/1012
# 174/1012
# 175/1012
# 176/1012
# 177/1012
# 178/1012
# 179/1012
# 180/1012
# 181/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 182/1012
# 183/1012
# 184/1012
# 185/1012
# 186/1012
# 187/1012
# 188/1012
# 189/1012
# 190/1012
# 191/1012
# 192/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 193/1012
# 194/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 195/1012
# 196/1012
# 197/1012
# 198/1012
# 199/1012
# 200/1012
# 201/1012
# 202/1012
# 203/1012
# 204/1012
# 205/1012
# 206/1012
# 207/1012
# 208/1012
# 209/1012
# 210/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 211/1012
# 212/1012
# 213/1012
# 214/1012
# 215/1012
# 216/1012
# 217/1012
# 218/1012
# 219/1012
# 220/1012
# 221/1012
# 222/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 223/1012
# 224/1012
# 225/1012
# 226/1012
# 227/1012
# 228/1012
# 229/1012
# 230/1012
# 231/1012
# 232/1012
# 233/1012
# 234/1012
# 235/1012
# 236/1012
# 237/1012
# 238/1012
# 239/1012
# 240/1012
# 241/1012
# 242/1012
# 243/1012
# 244/1012
# 245/1012
# 246/1012
# 247/1012
# 248/1012
# 249/1012
# 250/1012
# 251/1012
# 252/1012
# 253/1012
# 254/1012
# 255/1012
# 256/1012
# 257/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 258/1012
# 259/1012
# 260/1012
# 261/1012
# 262/1012
# 263/1012
# 264/1012
# 265/1012
# 266/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 267/1012
# 268/1012
# 269/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 270/1012
# 271/1012
# 272/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 273/1012
# 274/1012
# 275/1012
# 276/1012
# 277/1012
# 278/1012
# 279/1012
# 280/1012
# 281/1012
# 282/1012
# 283/1012
# 284/1012
# 285/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 286/1012
# 287/1012
# 288/1012
# 289/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 290/1012
# 291/1012
# 292/1012
# 293/1012
# 294/1012
# 295/1012
# 296/1012
# 297/1012
# 298/1012
# 299/1012
# 300/1012
# 301/1012
# 302/1012
# 303/1012
# 304/1012
# 305/1012
# 306/1012
# 307/1012
# 308/1012
# 309/1012
# 310/1012
# 311/1012
# 312/1012
# 313/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 314/1012
# 315/1012
# 316/1012
# 317/1012
# 318/1012
# 319/1012
# 320/1012
# 321/1012
# 322/1012
# 323/1012
# 324/1012
# 325/1012
# 326/1012
# 327/1012
# 328/1012
# 329/1012
# 330/1012
# 331/1012
# 332/1012
# 333/1012
# 334/1012
# 335/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 336/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 337/1012
# 338/1012
# 339/1012
# 340/1012
# 341/1012
# 342/1012
# 343/1012
# 344/1012
# 345/1012
# 346/1012
# 347/1012
# 348/1012
# 349/1012
# 350/1012
# 351/1012
# 352/1012
# 353/1012
# 354/1012
# 355/1012
# 356/1012
# 357/1012
# 358/1012
# 359/1012
# 360/1012
# 361/1012
# 362/1012
# 363/1012
# 364/1012
# 365/1012
# 366/1012
# 367/1012
# 368/1012
# 369/1012
# 370/1012
# 371/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 372/1012
# 373/1012
# 374/1012
# 375/1012
# 376/1012
# 377/1012
# 378/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 379/1012
# 380/1012
# 381/1012
# 382/1012
# 383/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 384/1012
# 385/1012
# 386/1012
# 387/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 388/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 389/1012
# 390/1012
# 391/1012
# 392/1012
# 393/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 394/1012
# 395/1012
# 396/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 397/1012
# 398/1012
# 399/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 125, in get_pages
#     raise PDFTextExtractionNotAllowed('Text extraction is not allowed: %r' % fp)
# pdfminer.pdfdocument.PDFTextExtractionNotAllowed: Text extraction is not allowed: <open file './papers/Non_Randomness_Stock_Market_Price_Model_Amended.pdf', mode 'rb' at 0x10124dc00>
# 400/1012
# 401/1012
# 402/1012
# 403/1012
# 404/1012
# 405/1012
# 406/1012
# 407/1012
# 408/1012
# 409/1012
# 410/1012
# 411/1012
# 412/1012
# 413/1012
# 414/1012
# 415/1012
# 416/1012
# 417/1012
# 418/1012
# 419/1012
# 420/1012
# 421/1012
# 422/1012
# 423/1012
# 424/1012
# 425/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 426/1012
# 427/1012
# 428/1012
# 429/1012
# 430/1012
# 431/1012
# 432/1012
# 433/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 434/1012
# 435/1012
# 436/1012
# 437/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 438/1012
# 439/1012
# 440/1012
# 441/1012
# 442/1012
# 443/1012
# 444/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 445/1012
# 446/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 447/1012
# 448/1012
# 449/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 450/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 451/1012
# 452/1012
# 453/1012
# 454/1012
# 455/1012
# 456/1012
# 457/1012
# 458/1012
# 459/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 460/1012
# 461/1012
# 462/1012
# 463/1012
# 464/1012
# 465/1012
# 466/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 110, in main
#     interpreter.process_page(page)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfinterp.py", line 839, in process_page
#     self.render_contents(page.resources, page.contents, ctm=ctm)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfinterp.py", line 850, in render_contents
#     self.init_resources(resources)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfinterp.py", line 356, in init_resources
#     self.fontmap[fontid] = self.rsrcmgr.get_font(objid, spec)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfinterp.py", line 204, in get_font
#     font = self.get_font(None, subspec)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfinterp.py", line 195, in get_font
#     font = PDFCIDFont(self, spec)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdffont.py", line 665, in __init__
#     BytesIO(self.fontfile.get_data()))
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdftypes.py", line 292, in get_data
#     self.decode()
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdftypes.py", line 273, in decode
#     if 'Predictor' in params:
# TypeError: argument of type 'NoneType' is not iterable
# 467/1012
# 468/1012
# 469/1012
# 470/1012
# 471/1012
# 472/1012
# 473/1012
# 474/1012
# 475/1012
# 476/1012
# 477/1012
# 478/1012
# 479/1012
# 480/1012
# 481/1012
# 482/1012
# 483/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 484/1012
# 485/1012
# 486/1012
# 487/1012
# 488/1012
# 489/1012
# 490/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 491/1012
# 492/1012
# 493/1012
# 494/1012
# 495/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 496/1012
# 497/1012
# 498/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 499/1012
# 500/1012
# 501/1012
# 502/1012
# 503/1012
# 504/1012
# 505/1012
# 506/1012
# 507/1012
# 508/1012
# 509/1012
# 510/1012
# 511/1012
# 512/1012
# 513/1012
# 514/1012
# 515/1012
# 516/1012
# 517/1012
# 518/1012
# 519/1012
# 520/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 521/1012
# 522/1012
# 523/1012
# 524/1012
# 525/1012
# 526/1012
# 527/1012
# 528/1012
# 529/1012
# 530/1012
# 531/1012
# 532/1012
# 533/1012
# 534/1012
# 535/1012
# 536/1012
# 537/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 538/1012
# 539/1012
# 540/1012
# 541/1012
# 542/1012
# 543/1012
# 544/1012
# 545/1012
# 546/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 547/1012
# 548/1012
# 549/1012
# 550/1012
# 551/1012
# 552/1012
# 553/1012
# 554/1012
# 555/1012
# 556/1012
# 557/1012
# 558/1012
# 559/1012
# 560/1012
# 561/1012
# 562/1012
# 563/1012
# 564/1012
# 565/1012
# 566/1012
# 567/1012
# 568/1012
# 569/1012
# 570/1012
# 571/1012
# 572/1012
# 573/1012
# 574/1012
# 575/1012
# 576/1012
# 577/1012
# 578/1012
# 579/1012
# 580/1012
# 581/1012
# 582/1012
# 583/1012
# 584/1012
# 585/1012
# 586/1012
# 587/1012
# 588/1012
# 589/1012
# 590/1012
# 591/1012
# 592/1012
# 593/1012
# 594/1012
# 595/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 596/1012
# 597/1012
# 598/1012
# 599/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 600/1012
# 601/1012
# 602/1012
# 603/1012
# 604/1012
# 605/1012
# 606/1012
# 607/1012
# 608/1012
# 609/1012
# 610/1012
# 611/1012
# 612/1012
# 613/1012
# 614/1012
# 615/1012
# 616/1012
# 617/1012
# 618/1012
# 619/1012
# 620/1012
# 621/1012
# 622/1012
# 623/1012
# 624/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 625/1012
# 626/1012
# 627/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# ...
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 811/1012
# 812/1012
# 813/1012
# 814/1012
# 815/1012
# 816/1012
# 817/1012
# 818/1012
# 819/1012
# 820/1012
# 821/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 822/1012
# 823/1012
# 824/1012
# 825/1012
# 826/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 827/1012
# 828/1012
# 829/1012
# 830/1012
# 831/1012
# 832/1012
# 833/1012
# 834/1012
# 835/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 836/1012
# 837/1012
# 838/1012
# 839/1012
# 840/1012
# 841/1012
# 842/1012
# 843/1012
# 844/1012
# 845/1012
# 846/1012
# 847/1012
# 848/1012
# 849/1012
# 850/1012
# 851/1012
# 852/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 853/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 854/1012
# 855/1012
# 856/1012
# 857/1012
# 858/1012
# 859/1012
# 860/1012
# 861/1012
# 862/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 863/1012
# 864/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 865/1012
# 866/1012
# 867/1012
# 868/1012
# 869/1012
# 870/1012
# 871/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 872/1012
# 873/1012
# 874/1012
# 875/1012
# 876/1012
# 877/1012
# 878/1012
# 879/1012
# 880/1012
# 881/1012
# 882/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 883/1012
# 884/1012
# 885/1012
# 886/1012
# 887/1012
# 888/1012
# 889/1012
# 890/1012
# 891/1012
# 892/1012
# 893/1012
# 894/1012
# 895/1012
# 896/1012
# 897/1012
# 898/1012
# 899/1012
# 900/1012
# 901/1012
# 902/1012
# 903/1012
# 904/1012
# 905/1012
# 906/1012
# 907/1012
# 908/1012
# 909/1012
# 910/1012
# 911/1012
# 912/1012
# 913/1012
# 914/1012
# 915/1012
# 916/1012
# 917/1012
# 918/1012
# 919/1012
# 920/1012
# 921/1012
# 922/1012
# 923/1012
# 924/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 925/1012
# 926/1012
# 927/1012
# 928/1012
# 929/1012
# 930/1012
# 931/1012
# 932/1012
# 933/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 125, in get_pages
#     raise PDFTextExtractionNotAllowed('Text extraction is not allowed: %r' % fp)
# pdfminer.pdfdocument.PDFTextExtractionNotAllowed: Text extraction is not allowed: <open file './papers/Activatability_for_simulation_tractability_of_NP_problems_Application_to_Ecology.pdf', mode 'rb' at 0x108da3c90>
# 934/1012
# 935/1012
# 936/1012
# 937/1012
# 938/1012
# 939/1012
# 940/1012
# 941/1012
# 942/1012
# 943/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 944/1012
# 945/1012
# 946/1012
# 947/1012
# 948/1012
# 949/1012
# 950/1012
# 951/1012
# 952/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 125, in get_pages
#     raise PDFTextExtractionNotAllowed('Text extraction is not allowed: %r' % fp)
# pdfminer.pdfdocument.PDFTextExtractionNotAllowed: Text extraction is not allowed: <open file './papers/Non_Randomness_Stock_Market_Price_Model.pdf', mode 'rb' at 0x100dd4c00>
# 953/1012
# 954/1012
# 955/1012
# 956/1012
# 957/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 958/1012
# 959/1012
# 960/1012
# 961/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 962/1012
# 963/1012
# 964/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 965/1012
# 966/1012
# 967/1012
# 968/1012
# 969/1012
# 970/1012
# 971/1012
# 972/1012
# 973/1012
# 974/1012
# 975/1012
# 976/1012
# 977/1012
# 978/1012
# 979/1012
# 980/1012
# 981/1012
# 982/1012
# 983/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 108, in main
#     caching=caching, check_extractable=True):
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfpage.py", line 122, in get_pages
#     doc = PDFDocument(parser, password=password, caching=caching)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfdocument.py", line 583, in __init__
#     raise PDFSyntaxError('No /Root object! - Is this really a PDF?')
# pdfminer.pdfparser.PDFSyntaxError: No /Root object! - Is this really a PDF?
# 984/1012
# 985/1012
# Traceback (most recent call last):
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 116, in <module>
#     if __name__ == '__main__': sys.exit(main(sys.argv))
#   File "/Users/AL/anaconda3/envs/python2/bin/pdf2txt.py", line 110, in main
#     interpreter.process_page(page)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfinterp.py", line 839, in process_page
#     self.render_contents(page.resources, page.contents, ctm=ctm)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfinterp.py", line 850, in render_contents
#     self.init_resources(resources)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfinterp.py", line 356, in init_resources
#     self.fontmap[fontid] = self.rsrcmgr.get_font(objid, spec)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfinterp.py", line 204, in get_font
#     font = self.get_font(None, subspec)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdfinterp.py", line 195, in get_font
#     font = PDFCIDFont(self, spec)
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdffont.py", line 665, in __init__
#     BytesIO(self.fontfile.get_data()))
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdftypes.py", line 292, in get_data
#     self.decode()
#   File "/Users/AL/anaconda3/envs/python2/lib/python2.7/site-packages/pdfminer/pdftypes.py", line 273, in decode
#     if 'Predictor' in params:
# TypeError: argument of type 'NoneType' is not iterable
# 986/1012
# 987/1012
# 988/1012
# 989/1012
# 990/1012
# 991/1012
# 992/1012
# 993/1012
# 994/1012
# 995/1012
# 996/1012
# 997/1012
# 998/1012
# 999/1012
# 1000/1012
# 1001/1012
# 1002/1012
# 1003/1012
# 1004/1012
# 1005/1012
# 1006/1012
# 1007/1012
# 1008/1012
# 1009/1012
# 1010/1012
# 1011/1012
